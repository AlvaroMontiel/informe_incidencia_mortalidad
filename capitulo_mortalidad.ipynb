# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # Importar datasets

# %% [markdown]
# path_defunciones = "D:\Datasets\defunciones_deis_abierto\DEF_1990_2018.csv"
# path_poblacion = "D:\Datasets\poblacion\pob_ine_censo2017_proyecciones.xlsx"
# path_poblacion_mundial = "D:\Datasets\poblacion\world_population_bysex.csv"

# %%
path_defunciones = "/Users/alvaro/Documents/Data_Science/datasets/defunciones/DEF_2010_2018.csv"
path_poblacion = "/Users/alvaro/Documents/Data_Science/datasets/poblacion/estimaciones-y-proyecciones-2002-2035-comunas.xlsx"
path_poblacion_mundial = "/Users/alvaro/Documents/Data_Science/datasets/poblacion/population_word_average20122013.csv"

# %%
df = pd.read_csv(path_defunciones, sep=';', encoding='Latin',
                                     dtype={21: str, 36: str, 37: str, 38: str, 39: str,
                                            40: str, 41: str, 42: str, 43: str, 44: str,
                                            45: str, 46: str, 47: str, 48: str, 49: str,
                                            50: str, 58: str, 60: str, 64: str, 67: str,
                                            69: str, 70: str, 71: str, 73: str, 76: str,
                                            82: str, 86: str, 89: str, 90: str, 91: str,
                                            93: str, 96: str, 97: str, 98: str, 99: str,
                                            100: str})

# %%
df_ = pd.read_excel(path_poblacion)

# %%
df_wp = pd.read_csv(path_poblacion_mundial, sep=';', encoding='Latin')

# %% [markdown]
# # Reducir datasets con las variables necesarias para el análisis

# %% [markdown]
# ## Poblaciones 2011 y 2014

# %%
df_poblacion = df_[['Region', 'Nombre Region', 'Provincia', 'Nombre Provincia',
                   'Comuna', 'Nombre Comuna', 'Sexo', 'Edad', 'Poblacion 2011', 'Poblacion 2014']].copy()

# %%
id(df_)
# Out:
# 5001223424

# %%
id(df_poblacion)
# Out:
# 5001185792

# %% [markdown]
# ## Variables seleccionadas para las Defunciones

# %%
columnas = list()

# %%
contador=0
for i in df.isna().sum().values.tolist():
    columnas.append(df.columns.values.tolist()[contador])
    columnas.append(i)
    contador+=1

# %%
df_defunciones = df[['ID_FALLECIDO', 'DIA_DEF', 'MES_DEF', 'ANO_DEF', 'FECHA_DEF', 'SEXO', 'GLOSA_SEXO',
                     'FECHA_NACIMIENTO', 'EDAD_CANT', 'EDAD_TIPO', 'GLOSA_EDAD_TIPO', 'OCUPACION', 'GLOSA_OCUPACION',
                     'CATEGORIA', 'GLOSA_CATEGORIA', 'REG_RES', 'GLOSA_REG_RES', 'COMUNA', 'GLOSA_COMUNA_RESIDENCIA',
                     'URBANO_RURAL', 'DIAG1', 'GLOSA_SUBCATEGORIA_DIAG1', 'CODIGO_CATEGORIA_DIAG1', 'GLOSA_CATEGORIA_DIAG1',
                     'CODIGO_GRUPO_DIAG1', 'GLOSA_GRUPO_DIAG1', 'CAPITULO_DIAG1', 'GLOSA_CAPITULO_DIAG1']]

# %%
df_defunciones.head()
# Out:
#                                ID_FALLECIDO  DIA_DEF  MES_DEF  ANO_DEF  \
# 0  5CE4D7C72073E82F977FD1FAF59C7C9DF75EDBE5     21.0       12     2018
# 1  B8BA0A061245955D2D32A4A9CADC36FA21030FC5      7.0        4     2018
# 2  4BF2BA7E947405362E9227808BAC8FBB29140883     29.0        3     2018
# 3  8095A9335642D38EB7E96B2057E444AD7D5A2B45     21.0        6     2018
# 4  AA67CF2FA18998CE68A8AF88560C795372132501      2.0        5     2018
#
#     FECHA_DEF  SEXO GLOSA_SEXO FECHA_NACIMIENTO  EDAD_CANT  EDAD_TIPO  ...  \
# 0  2018-12-21     2      Mujer       1960-09-11         58          1  ...
# 1  2018-04-07     2      Mujer       1961-06-13         56          1  ...
# 2  2018-03-29     1     Hombre       1962-03-11         56          1  ...
# 3  2018-06-21     2      Mujer       1963-03-21         55          1  ...
# 4  2018-05-02     2      Mujer       1962-09-20         55          1  ...
#
#   GLOSA_COMUNA_RESIDENCIA URBANO_RURAL DIAG1  \
# ...

# %%
df_defunciones.tail()
# Out:
#        ID_FALLECIDO  DIA_DEF  MES_DEF  ANO_DEF   FECHA_DEF  SEXO GLOSA_SEXO  \
# 913888          NaN     28.0        5     2017  2017-05-28     1     Hombre
# 913889          NaN     26.0       11     2018  2018-11-26     1     Hombre
# 913890          NaN      8.0        7     2017  2017-07-08     1     Hombre
# 913891          NaN     26.0        8     2017  2017-08-26     1     Hombre
# 913892          NaN     16.0       11     2018  2018-11-16     1     Hombre
#
#        FECHA_NACIMIENTO  EDAD_CANT  EDAD_TIPO  ... GLOSA_COMUNA_RESIDENCIA  \
# 913888       1983-11-04         33          1  ...                Santiago
# 913889       1986-02-22         32          1  ...              Santa Cruz
# 913890       1983-09-09         33          1  ...             Antofagasta
# 913891       1988-10-26         28          1  ...                 Iquique
# 913892       1992-11-04         26          1  ...                  Calama
#
# ...

# %% [markdown]
# # Filtros

# %% [markdown]
# ## Filtro por Año y por cáncer (C00-D48)

# %%
df_defunciones = df_defunciones.query('ANO_DEF >= 2010 & ANO_DEF <= 2015 &  CAPITULO_DIAG1 == "C00-D48"')

# %%
id(df_defunciones)
# Out:
# 4992863680

# %%
df_defunciones.dtypes
# Out:
# ID_FALLECIDO                 object
# DIA_DEF                     float64
# MES_DEF                       int64
# ANO_DEF                       int64
# FECHA_DEF                    object
# SEXO                          int64
# GLOSA_SEXO                   object
# FECHA_NACIMIENTO             object
# EDAD_CANT                     int64
# EDAD_TIPO                     int64
# GLOSA_EDAD_TIPO              object
# OCUPACION                    object
# GLOSA_OCUPACION              object
# CATEGORIA                     int64
# GLOSA_CATEGORIA              object
# REG_RES                       int64
# GLOSA_REG_RES                object
# COMUNA                        int64
# GLOSA_COMUNA_RESIDENCIA      object
# URBANO_RURAL                  int64
# DIAG1                        object
# GLOSA_SUBCATEGORIA_DIAG1     object
# CODIGO_CATEGORIA_DIAG1       object
# GLOSA_CATEGORIA_DIAG1        object
# CODIGO_GRUPO_DIAG1           object
# GLOSA_GRUPO_DIAG1            object
# ...

# %%
df_defunciones['DIA_DEF'] = pd.to_numeric(df_defunciones['DIA_DEF'], downcast ='signed')
df_defunciones['MES_DEF'] = pd.to_numeric(df_defunciones['MES_DEF'], downcast ='signed')
df_defunciones['ANO_DEF'] = pd.to_numeric(df_defunciones['ANO_DEF'], downcast ='signed')
df_defunciones['SEXO'] = pd.to_numeric(df_defunciones['SEXO'], downcast ='signed')
df_defunciones['EDAD_CANT'] = pd.to_numeric(df_defunciones['EDAD_CANT'], downcast ='signed')
df_defunciones['EDAD_TIPO'] = pd.to_numeric(df_defunciones['EDAD_TIPO'], downcast ='signed')
df_defunciones['CATEGORIA'] = pd.to_numeric(df_defunciones['CATEGORIA'], downcast ='signed')
df_defunciones['REG_RES'] = pd.to_numeric(df_defunciones['REG_RES'], downcast ='signed')
df_defunciones['COMUNA'] = pd.to_numeric(df_defunciones['COMUNA'], downcast ='signed')
df_defunciones['URBANO_RURAL'] = pd.to_numeric(df_defunciones['URBANO_RURAL'], downcast ='signed')

# %%
df_defunciones.isna().sum()
# Out:
# ID_FALLECIDO                103
# DIA_DEF                       0
# MES_DEF                       0
# ANO_DEF                       0
# FECHA_DEF                     0
# SEXO                          0
# GLOSA_SEXO                    0
# FECHA_NACIMIENTO             23
# EDAD_CANT                     0
# EDAD_TIPO                     0
# GLOSA_EDAD_TIPO               0
# OCUPACION                     0
# GLOSA_OCUPACION             272
# CATEGORIA                     0
# GLOSA_CATEGORIA               0
# REG_RES                       0
# GLOSA_REG_RES                 0
# COMUNA                        0
# GLOSA_COMUNA_RESIDENCIA       0
# URBANO_RURAL                  0
# DIAG1                         0
# GLOSA_SUBCATEGORIA_DIAG1      0
# CODIGO_CATEGORIA_DIAG1        0
# GLOSA_CATEGORIA_DIAG1         0
# CODIGO_GRUPO_DIAG1            0
# GLOSA_GRUPO_DIAG1             0
# CAPITULO_DIAG1                0
# GLOSA_CAPITULO_DIAG1          0
# dtype: int64

# %% [markdown]
# ## Eliminar las defunciones por D00-D09, D10-D36, D37-D44, D470, D472, D477, D479 y D48

# %% [markdown]
# Nota: Se analizarán solo los D45, D46, D47.1 y D47.3

# %%
df_defunciones.shape
# Out:
# (152686, 28)

# %%
df_defunciones.loc[df_defunciones['CODIGO_GRUPO_DIAG1'] == 'D00-D09']
# Out:
#                                     ID_FALLECIDO  DIA_DEF  MES_DEF  ANO_DEF  \
# 1120    6CC0F37770D6708A95137C4EDFF6931228EF6676       22        8     2010
# 326900  0460D6865FB0563E85A6658D40A12B7D818EE7F8        3        7     2015
# 351256  3A32D70F2B4072F4A1508CCB990C24C2E05C5389        2        7     2015
# 398863  10908BFA5300D8C5BE4F18482A97E64563A9851E       20        5     2015
# 400976  788453C5D225E2C5EE774FB39F615DA7AF9213CA        9        8     2015
# 454289  976F82820E691750C20702DB44AB3FF731E2D373       21        5     2014
# 506019  116CE623FBF94CF9E3DC0E3391694F0D879D84B3        6        7     2013
# 556556  7A45721B7F83B00BD791C0620C8A8B45EBB4F4EC       10        2     2013
# 598843  120DC0953236F53F37A1FF07A9DBAFC39CFF8249       30        3     2013
# 682088  7AA1C5025862DDA7F015CDA9AE51BB533D068D9A        9       11     2012
# 723222  B75BB2FE51620FD4AF95846F3644E5922A445A51        8        8     2011
# ...

# %%
df_defunciones = df_defunciones[df_defunciones.CODIGO_GRUPO_DIAG1 != 'D00-D09']

# %%
df_defunciones.shape
# Out:
# (152674, 28)

# %%
df_defunciones = df_defunciones[df_defunciones.CODIGO_GRUPO_DIAG1 != 'D10-D36']

# %%
df_defunciones.shape
# Out:
# (152120, 28)

# %%
df_defunciones = df_defunciones[df_defunciones.CODIGO_CATEGORIA_DIAG1 != 'D37']
df_defunciones = df_defunciones[df_defunciones.CODIGO_CATEGORIA_DIAG1 != 'D38']
df_defunciones = df_defunciones[df_defunciones.CODIGO_CATEGORIA_DIAG1 != 'D39']
df_defunciones = df_defunciones[df_defunciones.CODIGO_CATEGORIA_DIAG1 != 'D40']
df_defunciones = df_defunciones[df_defunciones.CODIGO_CATEGORIA_DIAG1 != 'D41']
df_defunciones = df_defunciones[df_defunciones.CODIGO_CATEGORIA_DIAG1 != 'D42']
df_defunciones = df_defunciones[df_defunciones.CODIGO_CATEGORIA_DIAG1 != 'D43']
df_defunciones = df_defunciones[df_defunciones.CODIGO_CATEGORIA_DIAG1 != 'D44']
df_defunciones = df_defunciones[df_defunciones.CODIGO_CATEGORIA_DIAG1 != 'D48']

# %%
df_defunciones.shape
# Out:
# (147736, 28)

# %%
df_defunciones = df_defunciones[df_defunciones.DIAG1 != 'D470']
df_defunciones = df_defunciones[df_defunciones.DIAG1 != 'D472']
df_defunciones = df_defunciones[df_defunciones.DIAG1 != 'D477']
df_defunciones = df_defunciones[df_defunciones.DIAG1 != 'D479']

# %%
df_defunciones.shape
# Out:
# (147483, 28)

# %% [markdown]
# # Crear nuevas columnas para la agrupación IARC

# %% [markdown]
# Columna CODIGO_CATEGORIA_IARC, GLOSA_CATEGORIA_IARC

# %%
condiciones = [
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C00'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C01') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C02'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C03') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C04') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C05') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C06'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C07') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C08'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C09'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C10'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C11'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C12') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C13'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C14'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C15'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C16'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C17'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C18'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C19') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C20'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C21'),    
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C22'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C23') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C24'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C25'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C30') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C31'), 
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C32'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C33') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C34'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C37') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C38'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C40') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C41'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C43'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C44'),    
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C45'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C46'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C47') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C48') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C49'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C50'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C51'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C52'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C53'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C54'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C55'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C56'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C57'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C58'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C60'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C61'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C62'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C63'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C64'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C65'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C66'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C67'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C68'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C69'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C70') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C71') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C72'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C73'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C74'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C75'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C26') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C39') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C76') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C77') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C78') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C79') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C80'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C81'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C82') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C83') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C84') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C85') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C86') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C96'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C88'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C90'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C91'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C92') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C93') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C94'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C95'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'C97'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'D45') | (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'D47'),
    (df_defunciones['CODIGO_CATEGORIA_DIAG1'] == 'D46'),
]

choice_1 = ["C00", "C01-C02", "C03-C06", "C07-C08", "C09", "C10", "C11", "C12-C13", "C14", "C15", "C16", "C17", "C18", "C19-C20", "C21", "C22", "C23-C24", "C25",
           "C30-C31", "C32", "C33-C34", "C37-C38", "C40-C41", "C43", "C44", "C45", "C46", "C47-C49", "C50", "C51", "C52", "C53", "C54", "C55", "C56", "C57",
           "C58", "C60", "C61", "C62", "C63", "C64", "C65", "C66", "C67", "C68", "C69", "C70-C72", "C73", "C74", "C75", "C26, C39, C76-C80", 
           "C81", "C82-C85, C96", "C88", "C90", "C91", "C92-C94", "C95", "C97", "D45, D471, D473", "D46"]

# %%
choice_2 = ["Labio", "Lengua", "Cavidad oral", "Glándulas salivales", "Amígdala", "Otros orofaringe",
            "Nasofaringe", "Hipofaringe y seno piriforme", "Faringe y boca no especificada",   
           "Esófago", "Estómago", "Intestino delgado", "Colon", "Recto", "Ano", "Hígado", "Vesícula biliar",
            "Páncreas", "Cavidades nasales", "Laringe", "Tráquea, bronquios y pulmón", "Otros órganos torácicos",
            "Huesos y cartílagos", "Melanoma de piel", "Piel no melanoma", "Mesotelioma", "Sarcoma de Kaposi", 
            "Tejidos blandos", "Mama", "Vulva", "Vagina", "Cuello uterino", "Cuerpo uterino", "Útero SAI", "Ovario", 
            "Otros órganos genitales femeninos", "Placenta", "Pene", "Próstata", "Testículo", "Otros genitales masculinos",
            "Riñón", "Pelvis renal", "Uréter", "Vejiga urinaria", "Otros órganos urinarios", "Ojo",
            "Encéfalo y sistema nervioso", "Tiroides", "Glándula suprarenal", "Otras glándulas endocrinas", 
            "Primario desconocido", "Linfoma de Hodgkin", "Linfoma no Hodgkin", "M múltiples", "Mieloma múltiple",
            "Leucemia linfoide", "Leucemia mieloide", "Leucemia no especificada", 
            "Tumores malignos de sitios múltiples independientes", "Síndromes mieloproliferaticos crónicos",
            "Síndromes mielodisplásicos"]

# %%
df_defunciones['CODIGO_CATEGORIA_IARC'] = np.select(condiciones, choice_1, default='Not Specified')

# %%
df_defunciones['GLOSA_CATEGORIA_IARC'] = np.select(condiciones, choice_2, default='Not Specified')

# %%
df_defunciones[['CODIGO_CATEGORIA_DIAG1', 'CODIGO_CATEGORIA_IARC', 'GLOSA_CATEGORIA_IARC']]
# Out:
#        CODIGO_CATEGORIA_DIAG1 CODIGO_CATEGORIA_IARC  GLOSA_CATEGORIA_IARC
# 571                       C18                   C18                 Colon
# 584                       C61                   C61              Próstata
# 592                       C15                   C15               Esófago
# 598                       C21                   C21                   Ano
# 601                       C25                   C25              Páncreas
# ...                       ...                   ...                   ...
# 882005                    C80     C26, C39, C76-C80  Primario desconocido
# 882008                    C18                   C18                 Colon
# 882013                    C79     C26, C39, C76-C80  Primario desconocido
# 882020                    C91                   C91     Leucemia linfoide
# 882023                    C64                   C64                 Riñón
#
# [147483 rows x 3 columns]

# %%
df_defunciones[['CODIGO_CATEGORIA_IARC', 'CODIGO_CATEGORIA_DIAG1']].query('CODIGO_CATEGORIA_IARC == "Not Specified"').values.tolist()
# Out:
# []

# %%
df_defunciones[['GLOSA_CATEGORIA_IARC', 'CODIGO_CATEGORIA_DIAG1']].query('GLOSA_CATEGORIA_IARC == "Not Specified"').values.tolist()
# Out:
# []

# %% [markdown]
# # Crear columna con agrupación por edad

# %% [markdown]
# ### Edades quinquenales

# %% [markdown]
# ## Crear variable 'EDAD_AÑO'

# %% [markdown]
# SE TRANSFORMAN LAS EDADES TIPO 2, 3 Y 4 A 0 AÑOS

# %%
df_defunciones['EDAD_TIPO'].describe()
# Out:
# count    147483.000000
# mean          1.000475
# std           0.025773
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max           4.000000
# Name: EDAD_TIPO, dtype: float64

# %%
edad = df_defunciones[['EDAD_CANT', 'EDAD_TIPO']].values.tolist()

# %%
nueva_edad=list()
for i in edad:
    if i[1] == 1:
        nueva_edad.append(i[0])
    elif i[1] >= 2:
        nueva_edad.append(0)

# %%
df_defunciones['EDAD_AÑOS'] = nueva_edad

# %%
df_defunciones['EDAD_AÑOS'].describe()
# Out:
# count    147483.000000
# mean         69.885485
# std          14.617242
# min           0.000000
# 25%          62.000000
# 50%          72.000000
# 75%          81.000000
# max         114.000000
# Name: EDAD_AÑOS, dtype: float64

# %%
df_defunciones['EDAD_AÑOS'].isna().sum()
# Out:
# 0

# %%
df_defunciones['EDAD_AÑOS']
# Out:
# 571       95
# 584       81
# 592       98
# 598       88
# 601       93
#           ..
# 882005    42
# 882008    84
# 882013    51
# 882020     2
# 882023     2
# Name: EDAD_AÑOS, Length: 147483, dtype: int64

# %%
df_defunciones['EDAD_AÑOS'] = pd.to_numeric(df_defunciones['EDAD_AÑOS'], downcast ='signed')

# %% [markdown]
# ## Crear la variable 'EDAD_QUINQ' y 'GLOSA_EDAD_QUIN'

# %%
edad_años = df_defunciones['EDAD_AÑOS'].values.tolist()

# %%
codigo_edad = list()
glosa_edad = list()

for i in edad_años:
    if i >= 0 and i <= 4:
        codigo_edad.append(1)
        glosa_edad.append("0 a 4 años")
    elif i >= 5 and i <= 9:
        codigo_edad.append(2)
        glosa_edad.append("5 a 9 años")
    elif i >= 10 and i <= 14:
        codigo_edad.append(3)
        glosa_edad.append("10 a 14 años")
    elif i >= 15 and i <= 19:
        codigo_edad.append(4)
        glosa_edad.append("15 a 19 años")
    elif i >= 20 and i <= 24:
        codigo_edad.append(5)
        glosa_edad.append("20 a 24 años")
    elif i >= 25 and i <= 29:
        codigo_edad.append(6)
        glosa_edad.append("25 a 29 años")
    elif i >= 30 and i <= 34:
        codigo_edad.append(7)
        glosa_edad.append("30 a 34 años")
    elif i >= 35 and i <= 39:
        codigo_edad.append(8)
        glosa_edad.append("35 a 39 años")
    elif i >= 40 and i <= 44:
        codigo_edad.append(9)
        glosa_edad.append("40 a 44 años")
    elif i >= 45 and i <= 49:
        codigo_edad.append(10)
        glosa_edad.append("45 a 49 años")
    elif i >= 50 and i <= 54:
        codigo_edad.append(11)
        glosa_edad.append("50 a 54 años")
    elif i >= 55 and i <= 59:
        codigo_edad.append(12)
        glosa_edad.append("55 a 59 años")
    elif i >= 60 and i <= 64:
        codigo_edad.append(13)
        glosa_edad.append("60 a 64 años")
    elif i >= 65 and i <= 69:
        codigo_edad.append(14)
        glosa_edad.append("65 a 69 años")
    elif i >= 70 and i <= 74:
        codigo_edad.append(15)
        glosa_edad.append("70 a 74 años")
    elif i >= 75 and i <= 79:
        codigo_edad.append(16)
        glosa_edad.append("75 a 79 años")
    elif i >= 80:
        codigo_edad.append(17)
        glosa_edad.append("80 y más años")

# %%
df_defunciones['EDAD_QUIN'] = codigo_edad

# %%
df_defunciones['GLOSA_EDAD_QUIN']=glosa_edad

# %% [markdown]
# # CREAR VARIABLE TRIENIO

# %% [markdown]
# ## Se codifican los años 2010 a 2012 como 1 y 2013 a 2015 como 2

# %%
anos_def = df_defunciones['ANO_DEF'].values.tolist()

# %%
trienio=list()
for i in anos_def:
    if i == 2010 or i == 2011 or i == 2012:
        trienio.append(1)
    else:
        trienio.append(2)

# %%
df_defunciones['TRIENIO']=trienio

# %%
df_defunciones.isna().sum()
# Out:
# ID_FALLECIDO                 95
# DIA_DEF                       0
# MES_DEF                       0
# ANO_DEF                       0
# FECHA_DEF                     0
# SEXO                          0
# GLOSA_SEXO                    0
# FECHA_NACIMIENTO             22
# EDAD_CANT                     0
# EDAD_TIPO                     0
# GLOSA_EDAD_TIPO               0
# OCUPACION                     0
# GLOSA_OCUPACION             260
# CATEGORIA                     0
# GLOSA_CATEGORIA               0
# REG_RES                       0
# GLOSA_REG_RES                 0
# COMUNA                        0
# GLOSA_COMUNA_RESIDENCIA       0
# URBANO_RURAL                  0
# DIAG1                         0
# GLOSA_SUBCATEGORIA_DIAG1      0
# CODIGO_CATEGORIA_DIAG1        0
# GLOSA_CATEGORIA_DIAG1         0
# CODIGO_GRUPO_DIAG1            0
# GLOSA_GRUPO_DIAG1             0
# CAPITULO_DIAG1                0
# GLOSA_CAPITULO_DIAG1          0
# CODIGO_CATEGORIA_IARC         0
# ...

# %% [markdown]
# # Cálculo de poblaciones

# %%
df_poblacion.head()
# Out:
#    Region Nombre Region  Provincia Nombre Provincia  Comuna Nombre Comuna  \
# 0       1      Tarapacá         11          Iquique    1101       Iquique
# 1       1      Tarapacá         11          Iquique    1101       Iquique
# 2       1      Tarapacá         11          Iquique    1101       Iquique
# 3       1      Tarapacá         11          Iquique    1101       Iquique
# 4       1      Tarapacá         11          Iquique    1101       Iquique
#
#    Sexo  Edad  Poblacion 2011  Poblacion 2014
# 0     1     0            1615            1596
# 1     1     1            1582            1588
# 2     1     2            1543            1600
# 3     1     3            1454            1600
# 4     1     4            1390            1564

# %% [markdown]
# ## Codificar la edad quinquenal

# %%
edad_años_pob = df_poblacion['Edad'].values.tolist()

# %%
codigo_edad = list()
glosa_edad = list()

for i in edad_años_pob:
    if i >= 0 and i <= 4:
        codigo_edad.append(1)
        glosa_edad.append("0 a 4 años")
    elif i >= 5 and i <= 9:
        codigo_edad.append(2)
        glosa_edad.append("5 a 9 años")
    elif i >= 10 and i <= 14:
        codigo_edad.append(3)
        glosa_edad.append("10 a 14 años")
    elif i >= 15 and i <= 19:
        codigo_edad.append(4)
        glosa_edad.append("15 a 19 años")
    elif i >= 20 and i <= 24:
        codigo_edad.append(5)
        glosa_edad.append("20 a 24 años")
    elif i >= 25 and i <= 29:
        codigo_edad.append(6)
        glosa_edad.append("25 a 29 años")
    elif i >= 30 and i <= 34:
        codigo_edad.append(7)
        glosa_edad.append("30 a 34 años")
    elif i >= 35 and i <= 39:
        codigo_edad.append(8)
        glosa_edad.append("35 a 39 años")
    elif i >= 40 and i <= 44:
        codigo_edad.append(9)
        glosa_edad.append("40 a 44 años")
    elif i >= 45 and i <= 49:
        codigo_edad.append(10)
        glosa_edad.append("45 a 49 años")
    elif i >= 50 and i <= 54:
        codigo_edad.append(11)
        glosa_edad.append("50 a 54 años")
    elif i >= 55 and i <= 59:
        codigo_edad.append(12)
        glosa_edad.append("55 a 59 años")
    elif i >= 60 and i <= 64:
        codigo_edad.append(13)
        glosa_edad.append("60 a 64 años")
    elif i >= 65 and i <= 69:
        codigo_edad.append(14)
        glosa_edad.append("65 a 69 años")
    elif i >= 70 and i <= 74:
        codigo_edad.append(15)
        glosa_edad.append("70 a 74 años")
    elif i >= 75 and i <= 79:
        codigo_edad.append(16)
        glosa_edad.append("75 a 79 años")
    elif i >= 80:
        codigo_edad.append(17)
        glosa_edad.append("80 y más años")

# %%
df_poblacion['Edad_quinq'] = codigo_edad
df_poblacion['Nombre Edad'] = glosa_edad

# %% [markdown]
# ## Poblacion por region

# %%
group_poblacion = df_poblacion.groupby(['Region', 'Nombre Region', 'Sexo', 'Edad_quinq', 'Nombre Edad'], as_index=False)[['Poblacion 2011', 'Poblacion 2014']].sum()

# %%
group_poblacion
# Out:
#      Region Nombre Region  Sexo  Edad_quinq    Nombre Edad  Poblacion 2011  \
# 0         1      Tarapacá     1           1     0 a 4 años           13958
# 1         1      Tarapacá     1           2     5 a 9 años           12141
# 2         1      Tarapacá     1           3   10 a 14 años           12237
# 3         1      Tarapacá     1           4   15 a 19 años           13264
# 4         1      Tarapacá     1           5   20 a 24 años           13125
# ..      ...           ...   ...         ...            ...             ...
# 539      16         Ñuble     2          13   60 a 64 años           11123
# 540      16         Ñuble     2          14   65 a 69 años            9092
# 541      16         Ñuble     2          15   70 a 74 años            7702
# 542      16         Ñuble     2          16   75 a 79 años            5867
# 543      16         Ñuble     2          17  80 y más años            7646
#
#      Poblacion 2014
# 0             14745
# 1             12998
# ...

# %% [markdown]
# ## Crear la variable de hasheo en las poblaciones por region

# %%
group_poblacion_ = group_poblacion.copy()

# %%
group_poblacion_['Trienio_1'] = 1

# %%
group_poblacion_['Trienio_2'] = 2

# %%
datos_hash = group_poblacion_[['Region', 'Edad_quinq', 'Sexo', 'Trienio_1']].values.tolist()

# %%
hasheo_1=list()

for i in datos_hash:
    hasheo_1.append(hash(tuple(i)))

# %%
datos_hash = group_poblacion_[['Region', 'Edad_quinq', 'Sexo', 'Trienio_2']].values.tolist()
hasheo_2=list()

for i in datos_hash:
    hasheo_2.append(hash(tuple(i)))

# %%
group_poblacion_['HASHEO1']=hasheo_1

# %%
group_poblacion_['HASHEO2']=hasheo_2

# %%
unstack_poblacion = group_poblacion.unstack(level=2, fill_value=0)

# %%
type(unstack_poblacion)
# Out:
# pandas.core.frame.DataFrame

# %%
unstack_poblacion
# Out:
#                                               Poblacion 2011         \
# Sexo                                                       1      2
# Region Nombre Region Edad_quinq Nombre Edad
# 1      Tarapacá      1          0 a 4 años             13958  13402
#                      2          5 a 9 años             12141  11679
#                      3          10 a 14 años           12237  11779
#                      4          15 a 19 años           13264  12233
#                      5          20 a 24 años           13125  12057
# ...                                                      ...    ...
# 16     Ñuble         13         60 a 64 años           10633  11123
#                      14         65 a 69 años            8268   9092
#                      15         70 a 74 años            6373   7702
#                      16         75 a 79 años            4455   5867
#                      17         80 y más años           4885   7646
#
# ...

# %%
group_poblacion_
# Out:
#      Region Nombre Region  Sexo  Edad_quinq    Nombre Edad  Poblacion 2011  \
# 0         1      Tarapacá     1           1     0 a 4 años           13958
# 1         1      Tarapacá     1           2     5 a 9 años           12141
# 2         1      Tarapacá     1           3   10 a 14 años           12237
# 3         1      Tarapacá     1           4   15 a 19 años           13264
# 4         1      Tarapacá     1           5   20 a 24 años           13125
# ..      ...           ...   ...         ...            ...             ...
# 539      16         Ñuble     2          13   60 a 64 años           11123
# 540      16         Ñuble     2          14   65 a 69 años            9092
# 541      16         Ñuble     2          15   70 a 74 años            7702
# 542      16         Ñuble     2          16   75 a 79 años            5867
# 543      16         Ñuble     2          17  80 y más años            7646
#
#      Poblacion 2014  Trienio_1  Trienio_2              HASHEO1  \
# ...

# %% [markdown]
# ## Poblacion por comunas

# %%
group_poblacion_com = df_poblacion.groupby(['Comuna', 'Nombre Comuna', 'Sexo', 'Edad_quinq', 'Nombre Edad'])[['Poblacion 2011', 'Poblacion 2014']].sum()

# %%
unstack_poblacion_com = group_poblacion_com.unstack(level=2, fill_value=0)

# %%
group_poblacion_com
# Out:
#                                                     Poblacion 2011  \
# Comuna Nombre Comuna Sexo Edad_quinq Nombre Edad
# 1101   Iquique       1    1          0 a 4 años               7584
#                           2          5 a 9 años               6561
#                           3          10 a 14 años             6738
#                           4          15 a 19 años             7603
#                           5          20 a 24 años             7984
# ...                                                            ...
# 16305  San Nicolás   2    13         60 a 64 años              284
#                           14         65 a 69 años              232
#                           15         70 a 74 años              186
#                           16         75 a 79 años              141
#                           17         80 y más años             162
#
#                                                     Poblacion 2014
# ...

# %%
unstack_poblacion_com
# Out:
#                                               Poblacion 2011        \
# Sexo                                                       1     2
# Comuna Nombre Comuna Edad_quinq Nombre Edad
# 1101   Iquique       1          0 a 4 años              7584  7189
#                      2          5 a 9 años              6561  6343
#                      3          10 a 14 años            6738  6503
#                      4          15 a 19 años            7603  6996
#                      5          20 a 24 años            7984  7282
# ...                                                      ...   ...
# 16305  San Nicolás   13         60 a 64 años             285   284
#                      14         65 a 69 años             231   232
#                      15         70 a 74 años             180   186
#                      16         75 a 79 años             113   141
#                      17         80 y más años            116   162
#
# ...

# %% [markdown]
# # Número de defunciones

# %% [markdown]
# ## Defunciones por region

# %%
group_def = df_defunciones.groupby(['CODIGO_CATEGORIA_IARC','GLOSA_CATEGORIA_IARC', 'EDAD_QUIN', 'GLOSA_EDAD_QUIN', 'REG_RES', 'GLOSA_REG_RES', 'TRIENIO', 'SEXO'], as_index=False)[['DIA_DEF']].count()

# %%
group_def = group_def.sort_values(by=['CODIGO_CATEGORIA_IARC', 'TRIENIO',  'REG_RES', 'EDAD_QUIN' ])

# %%
group_def
# Out:
#       CODIGO_CATEGORIA_IARC        GLOSA_CATEGORIA_IARC  EDAD_QUIN  \
# 6                       C00                       Labio         12
# 20                      C00                       Labio         16
# 28                      C00                       Labio         17
# 0                       C00                       Labio          8
# 3                       C00                       Labio         10
# ...                     ...                         ...        ...
# 16253                   D46  Síndromes mielodisplásicos         11
# 16321                   D46  Síndromes mielodisplásicos         14
# 16322                   D46  Síndromes mielodisplásicos         14
# 16398                   D46  Síndromes mielodisplásicos         16
# 16444                   D46  Síndromes mielodisplásicos         17
#
#       GLOSA_EDAD_QUIN  REG_RES   GLOSA_REG_RES  TRIENIO  SEXO  DIA_DEF
# 6        55 a 59 años        2  De Antofagasta        1     2        1
# ...

# %% [markdown]
# ## Crear la variable para hashear y unir por la poblacion regional

# %%
datos_hash = group_def[['REG_RES', 'EDAD_QUIN', 'SEXO', 'TRIENIO']].values.tolist()

# %%
len(datos_hash)
# Out:
# 16445

# %%
hasheo=list()
for i in datos_hash:
    hasheo.append(hash(tuple(i)))

# %%
group_def['HASHEO']=hasheo

# %%
group_def
# Out:
#       CODIGO_CATEGORIA_IARC        GLOSA_CATEGORIA_IARC  EDAD_QUIN  \
# 6                       C00                       Labio         12
# 20                      C00                       Labio         16
# 28                      C00                       Labio         17
# 0                       C00                       Labio          8
# 3                       C00                       Labio         10
# ...                     ...                         ...        ...
# 16253                   D46  Síndromes mielodisplásicos         11
# 16321                   D46  Síndromes mielodisplásicos         14
# 16322                   D46  Síndromes mielodisplásicos         14
# 16398                   D46  Síndromes mielodisplásicos         16
# 16444                   D46  Síndromes mielodisplásicos         17
#
#       GLOSA_EDAD_QUIN  REG_RES   GLOSA_REG_RES  TRIENIO  SEXO  DIA_DEF  \
# 6        55 a 59 años        2  De Antofagasta        1     2        1
# ...

# %%
group_def = group_def.set_index('HASHEO').join(group_poblacion_.set_index('HASHEO1'))

# %%
group_def
# Out:
#                      CODIGO_CATEGORIA_IARC         GLOSA_CATEGORIA_IARC  \
# -9222976517645222821                   C00                        Labio
# -9222976517645222821                   C10             Otros orofaringe
# -9222976517645222821                   C15                      Esófago
# -9222976517645222821                   C16                     Estómago
# -9222976517645222821                   C17            Intestino delgado
# ...                                    ...                          ...
#  9206670991306487791               C70-C72  Encéfalo y sistema nervioso
#  9206670991306487791                   C73                     Tiroides
#  9206670991306487791          C82-C85, C96           Linfoma no Hodgkin
#  9206670991306487791                   C90             Mieloma múltiple
#  9206670991306487791               C92-C94            Leucemia mieloide
#
#                       EDAD_QUIN GLOSA_EDAD_QUIN  REG_RES    GLOSA_REG_RES  \
# ...

# %%
group_def = group_def.drop(['Region', 'Nombre Region', 'Sexo', 'Edad_quinq', 'Nombre Edad', 'Poblacion 2014', 'Trienio_1', 'Trienio_2', 'HASHEO2' ], axis=1)

# %%
group_def=group_def.rename(columns={'DIA_DEF':'NUM_DEF', 'Poblacion 2011': 'POB_2011'}, inplace=False)

# %%
group_def = group_def.join(group_poblacion_.set_index('HASHEO2'))

# %%
group_def = group_def.drop(['Region', 'Nombre Region', 'Sexo', 'Edad_quinq', 'Nombre Edad', 'Poblacion 2011', 'Trienio_1', 'Trienio_2', 'HASHEO1' ], axis=1)

# %%
group_def=group_def.rename(columns={'Poblacion 2014': 'POB_2014'}, inplace=False)

# %%
group_def[['POB_2011', 'POB_2014']] = group_def[['POB_2011', 'POB_2014']].fillna(0)

# %%
contador=0
poblacion=list()
pob14 = group_def['POB_2014'].values.tolist()
pob11 = group_def['POB_2011'].values.tolist()
for i in pob11:
    if i  == 0:
        poblacion.append(int(pob14[contador]))
    elif i > 0:
        poblacion.append(int(i))
    contador += 1

# %%
group_def['POBLACION']=poblacion

# %%
group_def = group_def.drop(['POB_2011', 'POB_2014' ], axis=1)

# %%
group_def
# Out:
#                      CODIGO_CATEGORIA_IARC         GLOSA_CATEGORIA_IARC  \
# -9222976517645222821                   C00                        Labio
# -9222976517645222821                   C10             Otros orofaringe
# -9222976517645222821                   C15                      Esófago
# -9222976517645222821                   C16                     Estómago
# -9222976517645222821                   C17            Intestino delgado
# ...                                    ...                          ...
#  9206670991306487791               C70-C72  Encéfalo y sistema nervioso
#  9206670991306487791                   C73                     Tiroides
#  9206670991306487791          C82-C85, C96           Linfoma no Hodgkin
#  9206670991306487791                   C90             Mieloma múltiple
#  9206670991306487791               C92-C94            Leucemia mieloide
#
#                       EDAD_QUIN GLOSA_EDAD_QUIN  REG_RES    GLOSA_REG_RES  \
# ...

# %% [markdown]
# ## Cálculo de la TBM por grupo etario

# %%
group_def['TBM']= group_def['NUM_DEF']/group_def['POBLACION']

# %%
group_def
# Out:
#                      CODIGO_CATEGORIA_IARC         GLOSA_CATEGORIA_IARC  \
# -9222976517645222821                   C00                        Labio
# -9222976517645222821                   C10             Otros orofaringe
# -9222976517645222821                   C15                      Esófago
# -9222976517645222821                   C16                     Estómago
# -9222976517645222821                   C17            Intestino delgado
# ...                                    ...                          ...
#  9206670991306487791               C70-C72  Encéfalo y sistema nervioso
#  9206670991306487791                   C73                     Tiroides
#  9206670991306487791          C82-C85, C96           Linfoma no Hodgkin
#  9206670991306487791                   C90             Mieloma múltiple
#  9206670991306487791               C92-C94            Leucemia mieloide
#
#                       EDAD_QUIN GLOSA_EDAD_QUIN  REG_RES    GLOSA_REG_RES  \
# ...

# %% [markdown]
# ## Cálculo de las muertes esperadas para la TMA

# %%
seleccion=group_def[['EDAD_QUIN','SEXO']].values.tolist()

# %%
df_wp
# Out:
#          age  population_male  population_female
# 0        0-4           343105             321007
# 1        5-9           326623             304589
# 2      10-14           314861             293940
# 3      15-19           309113             289937
# 4      20-24           312933             296777
# 5      25-29           299466             287637
# 6      30-34           266106             257762
# 7      35-39           251160             244568
# 8      40-44           241867             237478
# 9      45-49           219223             217174
# 10     50-54           188102             188410
# 11     55-59           161577             165183
# 12     60-64           129759             136817
# 13     65-69            91803             100947
# 14     70-74            67575              79000
# 15     75-79            47319              60763
# 16  80 y ms            43678              71947

# %%
pob_h = df_wp['population_male'].values.tolist()

# %%
pob_m = df_wp['population_female'].values.tolist()

# %%
pob_m
# Out:
# [321007,
#  304589,
#  293940,
#  289937,
#  296777,
#  287637,
#  257762,
#  244568,
#  237478,
#  217174,
#  188410,
#  165183,
#  136817,
#  100947,
#  79000,
#  60763,
#  71947]

# %%
pob_estandar=list()
for i in seleccion:
    if i[0]==1:
        if i[1]==1:
            pob_estandar.append(pob_h[0])
        elif i[1] == 2:
            pob_estandar.append(pob_m[0])
    elif i[0]==2:
        if i[1]==1:
            pob_estandar.append(pob_h[1])
        elif i[1] == 2:
            pob_estandar.append(pob_m[1])
    elif i[0]==3:
        if i[1]==1:
            pob_estandar.append(pob_h[2])
        elif i[1] == 2:
            pob_estandar.append(pob_m[2])
    elif i[0]==4:
        if i[1]==1:
            pob_estandar.append(pob_h[3])
        elif i[1] == 2:
            pob_estandar.append(pob_m[3])
    elif i[0]==5:
        if i[1]==1:
            pob_estandar.append(pob_h[4])
        elif i[1] == 2:
            pob_estandar.append(pob_m[4])
    elif i[0]==6:
        if i[1]==1:
            pob_estandar.append(pob_h[5])
        elif i[1] == 2:
            pob_estandar.append(pob_m[5])
    elif i[0]==7:
        if i[1]==1:
            pob_estandar.append(pob_h[6])
        elif i[1] == 2:
            pob_estandar.append(pob_m[6])
    elif i[0]==8:
        if i[1]==1:
            pob_estandar.append(pob_h[7])
        elif i[1] == 2:
            pob_estandar.append(pob_m[7])
    elif i[0]==9:
        if i[1]==1:
            pob_estandar.append(pob_h[8])
        elif i[1] == 2:
            pob_estandar.append(pob_m[8])
    elif i[0]==10:
        if i[1]==1:
            pob_estandar.append(pob_h[9])
        elif i[1] == 2:
            pob_estandar.append(pob_m[9])
    elif i[0]==11:
        if i[1]==1:
            pob_estandar.append(pob_h[10])
        elif i[1] == 2:
            pob_estandar.append(pob_m[10])
    elif i[0]==12:
        if i[1]==1:
            pob_estandar.append(pob_h[11])
        elif i[1] == 2:
            pob_estandar.append(pob_m[11])
    elif i[0]==13:
        if i[1]==1:
            pob_estandar.append(pob_h[12])
        elif i[1] == 2:
            pob_estandar.append(pob_m[12])
    elif i[0]==14:
        if i[1]==1:
            pob_estandar.append(pob_h[13])
        elif i[1] == 2:
            pob_estandar.append(pob_m[13])
    elif i[0]==15:
        if i[1]==1:
            pob_estandar.append(pob_h[14])
        elif i[1] == 2:
            pob_estandar.append(pob_m[14])
    elif i[0]==16:
        if i[1]==1:
            pob_estandar.append(pob_h[15])
        elif i[1] == 2:
            pob_estandar.append(pob_m[15])
    elif i[0]==17:
        if i[1]==1:
            pob_estandar.append(pob_h[16])
        elif i[1] == 2:
            pob_estandar.append(pob_m[16])

# %%
len(pob_estandar)
# Out:
# 16445

# %%
group_def['POB_ESTANDAR'] = pob_estandar

# %%
group_def['MUERTES_ESPERADAS'] = group_def['TBM'] * group_def['POB_ESTANDAR']

# %%
group_def
# Out:
#                      CODIGO_CATEGORIA_IARC         GLOSA_CATEGORIA_IARC  \
# -9222976517645222821                   C00                        Labio
# -9222976517645222821                   C10             Otros orofaringe
# -9222976517645222821                   C15                      Esófago
# -9222976517645222821                   C16                     Estómago
# -9222976517645222821                   C17            Intestino delgado
# ...                                    ...                          ...
#  9206670991306487791               C70-C72  Encéfalo y sistema nervioso
#  9206670991306487791                   C73                     Tiroides
#  9206670991306487791          C82-C85, C96           Linfoma no Hodgkin
#  9206670991306487791                   C90             Mieloma múltiple
#  9206670991306487791               C92-C94            Leucemia mieloide
#
#                       EDAD_QUIN GLOSA_EDAD_QUIN  REG_RES    GLOSA_REG_RES  \
# ...

# %% [markdown]
# ## Nuevo dataframe para la constrónucci de la TBM por causas, región y trienios

# %%
group_def = group_def.sort_values(by=['CODIGO_CATEGORIA_IARC', 'TRIENIO',  'REG_RES'])

# %%
group_def
# Out:
#                      CODIGO_CATEGORIA_IARC        GLOSA_CATEGORIA_IARC  \
#  3833099694026631422                   C00                       Labio
#  8277197492416471183                   C00                       Labio
#  122632594699170798                    C00                       Labio
# -6418075019267743748                   C00                       Labio
# -717079791663054677                    C00                       Labio
# ...                                    ...                         ...
# -1858638918047319156                   D46  Síndromes mielodisplásicos
#  5686216093552077384                   D46  Síndromes mielodisplásicos
#  6378685606920315424                   D46  Síndromes mielodisplásicos
#  7743699689930707306                   D46  Síndromes mielodisplásicos
#  8516095850306856116                   D46  Síndromes mielodisplásicos
#
#                       EDAD_QUIN GLOSA_EDAD_QUIN  REG_RES   GLOSA_REG_RES  \
# ...

# %%
group_def.to_excel("/Users/alvaro/Documents/Data_Science/datasets/defunciones/group_def.xlsx",sheet_name='resultado')

# %%
a = group_def.groupby(['CODIGO_CATEGORIA_IARC','GLOSA_CATEGORIA_IARC','REG_RES', 'GLOSA_REG_RES', 'TRIENIO','SEXO'], as_index=False)['NUM_DEF'].sum()

# %%
a.query('REG_RES == 5 & CODIGO_CATEGORIA_IARC == "C15"')
# Out:
#     CODIGO_CATEGORIA_IARC GLOSA_CATEGORIA_IARC  REG_RES  GLOSA_REG_RES  \
# 376                   C15              Esófago        5  De Valparaíso
# 377                   C15              Esófago        5  De Valparaíso
# 378                   C15              Esófago        5  De Valparaíso
# 379                   C15              Esófago        5  De Valparaíso
#
#      TRIENIO  SEXO  NUM_DEF  POBLACION       TMB
# 376        1     1      125     863426  4.825737
# 377        1     2       90     903132  3.321774
# 378        2     1      119     891643  4.448716
# 379        2     2       71     933199  2.536079

# %%
a.query('REG_RES == 2 & SEXO == 1 & TRIENIO == 2')
# Out:
#      CODIGO_CATEGORIA_IARC                               GLOSA_CATEGORIA_IARC  \
# 35                 C01-C02                                             Lengua
# 87                 C03-C06                                       Cavidad oral
# 140                C07-C08                                Glándulas salivales
# 192                    C09                                           Amígdala
# 255                    C11                                        Nasofaringe
# 326                    C14                     Faringe y boca no especificada
# 366                    C15                                            Esófago
# 430                    C16                                           Estómago
# 493                    C17                                  Intestino delgado
# 546                    C18                                              Colon
# 610                C19-C20                                              Recto
# ...

# %%
poblacion_tasabruta = group_poblacion.groupby(['Region','Nombre Region', 'Sexo'], as_index=False)['Poblacion 2011', 'Poblacion 2014'].sum()
# Out:
# /var/folders/bn/1gnxsrr57psgnfmcg9tz005m0000gn/T/ipykernel_3171/1839680386.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   poblacion_tasabruta = group_poblacion.groupby(['Region','Nombre Region', 'Sexo'], as_index=False)['Poblacion 2011', 'Poblacion 2014'].sum()

# %%
poblacion_tasabruta
# Out:
#     Region                              Nombre Region  Sexo  Poblacion 2011  \
# 0        1                                   Tarapacá     1          153017
# 1        1                                   Tarapacá     2          148126
# 2        2                                Antofagasta     1          289719
# 3        2                                Antofagasta     2          280588
# 4        3                                    Atacama     1          146360
# 5        3                                    Atacama     2          142654
# 6        4                                   Coquimbo     1          353125
# 7        4                                   Coquimbo     2          365638
# 8        5                                 Valparaíso     1          863426
# 9        5                                 Valparaíso     2          903132
# 10       6      Libertador General Bernardo O'Higgins     1          446519
# ...

# %%
def_poblacion = a[['REG_RES', 'SEXO', 'TRIENIO']].values.tolist()

# %%
poblacion_lista = poblacion_tasabruta[['Region', 'Sexo', 'Poblacion 2011', 'Poblacion 2014']].values.tolist()

# %%
len(poblacion_lista)
# Out:
# 32

# %%
len(def_poblacion)
# Out:
# 2874

# %%
pob_tmb = list()
for i in def_poblacion:
    if i[0] == 1: ## Esto es la región
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 1, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[0][2])
            elif i[2] == 2: ## Región 1, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[0][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 1, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[1][2])
            elif i[2] == 2: ## Región 1, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[1][3])
    
    elif i[0] == 2:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 2, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[2][2])
            elif i[2] == 2: ## Región 2, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[2][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 2, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[3][2])
            elif i[2] == 2: ## Región 2, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[3][3])   
    
    elif i[0] == 3:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 3, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[4][2])
            elif i[2] == 2: ## Región 3, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[4][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 3, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[5][2])
            elif i[2] == 2: ## Región 3, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[5][3]) 
    
    elif i[0] == 4:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 4, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[6][2])
            elif i[2] == 2: ## Región 4, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[6][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 4, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[7][2])
            elif i[2] == 2: ## Región 4, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[7][3]) 
    
    elif i[0] == 5:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 5, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[8][2])
            elif i[2] == 2: ## Región 5, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[8][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 5, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[9][2])
            elif i[2] == 2: ## Región 5, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[9][3]) 
    
    elif i[0] == 6:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 6, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[10][2])
            elif i[2] == 2: ## Región 6, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[10][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 6, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[11][2])
            elif i[2] == 2: ## Región 6, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[11][3]) 
    
    elif i[0] == 7:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 7, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[12][2])
            elif i[2] == 2: ## Región 7, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[12][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 7, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[13][2])
            elif i[2] == 2: ## Región 7, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[13][3])
    
    elif i[0] == 8:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 7, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[14][2])
            elif i[2] == 2: ## Región 7, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[14][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 8, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[15][2])
            elif i[2] == 2: ## Región 8, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[15][3])
    
    elif i[0] == 9:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 9, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[16][2])
            elif i[2] == 2: ## Región 9, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[16][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 9, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[17][2])
            elif i[2] == 2: ## Región 9, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[17][3])
    
    elif i[0] == 10:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 10, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[18][2])
            elif i[2] == 2: ## Región 10, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[18][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 10, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[19][2])
            elif i[2] == 2: ## Región 10, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[19][3])
    
    elif i[0] == 11:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 11, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[20][2])
            elif i[2] == 2: ## Región 11, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[20][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 11, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[21][2])
            elif i[2] == 2: ## Región 11, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[21][3])
    
    elif i[0] == 12:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 12, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[22][2])
            elif i[2] == 2: ## Región 12, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[22][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 12, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[23][2])
            elif i[2] == 2: ## Región 12, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[23][3])
    
    elif i[0] == 13:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 13, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[24][2])
            elif i[2] == 2: ## Región 13, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[24][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 13, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[25][2])
            elif i[2] == 2: ## Región 13, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[25][3])
    
    elif i[0] == 14:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 14, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[26][2])
            elif i[2] == 2: ## Región 14, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[26][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 14, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[27][2])
            elif i[2] == 2: ## Región 14, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[27][3])
    
    elif i[0] == 15:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 15, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[28][2])
            elif i[2] == 2: ## Región 15, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[28][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 15, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[29][2])
            elif i[2] == 2: ## Región 15, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[29][3])
    
    elif i[0] == 16:
        if i[1] == 1: ## Hombres
            if i[2] == 1: ## Región 16, sexo 1, trienio 1
                pob_tmb.append(poblacion_lista[30][2])
            elif i[2] == 2: ## Región 16, sexo 1, trienio 2
                pob_tmb.append(poblacion_lista[30][3])
        elif i[1] == 2: ## Mujeres
            if i[2] == 1: ## Región 16, sexo 2, trienio 1
                pob_tmb.append(poblacion_lista[31][2])
            elif i[2] == 2: ## Región 16, sexo 2, trienio 2
                pob_tmb.append(poblacion_lista[31][3])

# %%
len(pob_tmb)
# Out:
# 2874

# %%
a['POBLACION']=pob_tmb

# %%
a['TMB']=(a['NUM_DEF']/3)/a['POBLACION']*100000

# %%
tasa_bruta = a['TMB'].values.tolist()

# %%
max(tasa_bruta)
# Out:
# 41.926223087226404

# %%
a
# Out:
#      CODIGO_CATEGORIA_IARC        GLOSA_CATEGORIA_IARC  REG_RES  \
# 0                      C00                       Labio        2
# 1                      C00                       Labio        2
# 2                      C00                       Labio        3
# 3                      C00                       Labio        4
# 4                      C00                       Labio        4
# ...                    ...                         ...      ...
# 2869                   D46  Síndromes mielodisplásicos       15
# 2870                   D46  Síndromes mielodisplásicos       16
# 2871                   D46  Síndromes mielodisplásicos       16
# 2872                   D46  Síndromes mielodisplásicos       16
# 2873                   D46  Síndromes mielodisplásicos       16
#
#               GLOSA_REG_RES  TRIENIO  SEXO  NUM_DEF  POBLACION       TMB
# 0            De Antofagasta        1     1        1     289719  0.115054
# ...

# %% [markdown]
# # Agregar TMA al dataframe a

# %%
a
# Out:
#      CODIGO_CATEGORIA_IARC        GLOSA_CATEGORIA_IARC  REG_RES  \
# 0                      C00                       Labio        2
# 1                      C00                       Labio        2
# 2                      C00                       Labio        3
# 3                      C00                       Labio        4
# 4                      C00                       Labio        4
# ...                    ...                         ...      ...
# 2869                   D46  Síndromes mielodisplásicos       15
# 2870                   D46  Síndromes mielodisplásicos       16
# 2871                   D46  Síndromes mielodisplásicos       16
# 2872                   D46  Síndromes mielodisplásicos       16
# 2873                   D46  Síndromes mielodisplásicos       16
#
#               GLOSA_REG_RES  TRIENIO  SEXO  NUM_DEF  POBLACION       TMB
# 0            De Antofagasta        1     1        1     289719  0.115054
# ...

# %%
group_def
# Out:
#                      CODIGO_CATEGORIA_IARC        GLOSA_CATEGORIA_IARC  \
#  3833099694026631422                   C00                       Labio
#  8277197492416471183                   C00                       Labio
#  122632594699170798                    C00                       Labio
# -6418075019267743748                   C00                       Labio
# -717079791663054677                    C00                       Labio
# ...                                    ...                         ...
# -1858638918047319156                   D46  Síndromes mielodisplásicos
#  5686216093552077384                   D46  Síndromes mielodisplásicos
#  6378685606920315424                   D46  Síndromes mielodisplásicos
#  7743699689930707306                   D46  Síndromes mielodisplásicos
#  8516095850306856116                   D46  Síndromes mielodisplásicos
#
#                       EDAD_QUIN GLOSA_EDAD_QUIN  REG_RES   GLOSA_REG_RES  \
# ...

# %%
esperadas = group_def.groupby(['CODIGO_CATEGORIA_IARC', 'REG_RES','TRIENIO', 'SEXO' ], as_index=False)[['MUERTES_ESPERADAS']].sum()

# %%
len(esperadas.values.tolist())
# Out:
# 2874

# %%
esperadas.values.tolist()
# Out:
# [['C00', 2, 1, 1, 16.82752489331437],
#  ['C00', 2, 1, 2, 11.654766104565017],
#  ['C00', 3, 2, 1, 20.580333068992864],
#  ['C00', 4, 1, 2, 6.962837510887448],
#  ['C00', 4, 2, 2, 5.962787999336981],
#  ['C00', 5, 1, 1, 13.5796954992142],
#  ['C00', 5, 1, 2, 2.231606699751861],
#  ['C00', 5, 2, 1, 7.0327175020551485],
#  ['C00', 7, 1, 1, 9.433693304535637],
#  ['C00', 7, 2, 1, 4.959997064004697],
#  ['C00', 8, 1, 1, 7.07450599287334],
#  ['C00', 8, 1, 2, 7.092523957994899],
#  ['C00', 8, 2, 1, 17.149010690325873],
#  ['C00', 8, 2, 2, 6.89822330703298],
#  ['C00', 9, 1, 1, 4.693531055233183],
#  ['C00', 9, 2, 1, 10.891702378012463],
#  ['C00', 10, 1, 1, 7.579186512910503],
#  ['C00', 10, 1, 2, 6.457278765033208],
#  ['C00', 11, 2, 2, 62.67160278745644],
#  ['C00', 12, 2, 1, 34.691348973607035],
#  ['C00', 13, 1, 1, 3.051152305365515],
#  ['C00', 13, 1, 2, 0.864957190093503],
#  ['C00', 13, 2, 1, 1.8023275308207505],
#  ['C00', 13, 2, 2, 0.6148633057865366],
# ...

# %% [markdown]
# # Defunciones por comuna

# %%
group_def_com = df_defunciones.groupby(['CODIGO_CATEGORIA_IARC','GLOSA_CATEGORIA_IARC', 'EDAD_QUIN', 'GLOSA_EDAD_QUIN', 'COMUNA', 'GLOSA_COMUNA_RESIDENCIA', 'ANO_DEF', 'SEXO'], as_index=False)[['DIA_DEF']].count()

# %%
group_def_com
# Out:
#       CODIGO_CATEGORIA_IARC        GLOSA_CATEGORIA_IARC  EDAD_QUIN  \
# 0                       C00                       Labio          8
# 1                       C00                       Labio          9
# 2                       C00                       Labio          9
# 3                       C00                       Labio         10
# 4                       C00                       Labio         10
# ...                     ...                         ...        ...
# 97469                   D46  Síndromes mielodisplásicos         17
# 97470                   D46  Síndromes mielodisplásicos         17
# 97471                   D46  Síndromes mielodisplásicos         17
# 97472                   D46  Síndromes mielodisplásicos         17
# 97473                   D46  Síndromes mielodisplásicos         17
#
#       GLOSA_EDAD_QUIN  COMUNA GLOSA_COMUNA_RESIDENCIA  ANO_DEF  SEXO  DIA_DEF
# 0        35 a 39 años    5601             San Antonio     2011     1        1
# ...

# %%
numero_defunciones_com = group_def_com.values.tolist()

# %%
len(numero_defunciones_com)
# Out:
# 97474
