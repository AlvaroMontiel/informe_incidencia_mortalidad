# %% [markdown]
# # Importar paquetes

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Cargar archivos

# %%
path = "/Users/alvaro/Documents/Data_Science/datasets/defunciones/"
path_ = "/Users/alvaro/Desktop/"

# %%
#path = "D:\\Datasets\\defunciones_deis_abierto\\"
#path_ =  'D:\\Datasets\\poblacion\\'

# %%
nom = "DEF_2010_2018.csv"
nom_ = "estimaciones-y-proyecciones-2002-2035-comunas.xlsx"  
defunciones = path+nom
poblacion = path_+nom_

# %%
#nom = "DEF_1990_2018.csv"
#nom_ = "pob_ine_censo2017_proyecciones.xlsx"  
#defunciones = path+nom
#poblacion = path_+nom_

# %%
df = pd.read_csv(defunciones, sep=';', encoding='Latin-1')
df_ = pd.read_excel(poblacion)
# Out:
# /usr/local/Cellar/jupyterlab/3.1.14_1/libexec/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (21,58,60,64,67,69,70,71,73,76,82,86,89,90,91,93,96,97,98,99,100) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Variables condicionales (edad tipo)

# %%
choice_list = ['00-04 años','05-09 años','10-14 años',
              '15-19 años', '20-24 años', '25-29 años',
              '30-34 años', '35-39 años', '40-44 años',
              '45-49 años', '50-54 años', '55-59 años',
              '60-64 años', '65-69 años', '70-74 años',
              '75-79 años', '80 y más']
condiciones = [(df['EDAD_TIPO'] >= 2) | (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] <= 4),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 5) & (df['EDAD_CANT'] <= 9),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 10) & (df['EDAD_CANT'] <= 14),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 15) & (df['EDAD_CANT'] <= 19),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 20) & (df['EDAD_CANT'] <= 24),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 25) & (df['EDAD_CANT'] <= 29),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 30) & (df['EDAD_CANT'] <= 34),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 35) & (df['EDAD_CANT'] <= 39),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 40) & (df['EDAD_CANT'] <= 44),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 45) & (df['EDAD_CANT'] <= 49),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 50) & (df['EDAD_CANT'] <= 54),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 55) & (df['EDAD_CANT'] <= 59),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 60) & (df['EDAD_CANT'] <= 64),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 65) & (df['EDAD_CANT'] <= 69),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 70) & (df['EDAD_CANT'] <= 74),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 75) & (df['EDAD_CANT'] <= 79),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 80)]
df['edad_grupo'] = np.select(condiciones, choice_list, default='Not Specified')
condiciones = [(df_['Edad'] >= 0) & (df_['Edad'] <= 4),
              (df_['Edad'] >= 5) & (df_['Edad'] <= 9),
              (df_['Edad'] >= 10) & (df_['Edad'] <= 14),
              (df_['Edad'] >= 15) & (df_['Edad'] <= 19),
              (df_['Edad'] >= 20) & (df_['Edad'] <= 24),
              (df_['Edad'] >= 25) & (df_['Edad'] <= 29),
              (df_['Edad'] >= 30) & (df_['Edad'] <= 34),
              (df_['Edad'] >= 35) & (df_['Edad'] <= 39),
              (df_['Edad'] >= 40) & (df_['Edad'] <= 44),
              (df_['Edad'] >= 45) & (df_['Edad'] <= 49),
              (df_['Edad'] >= 50) & (df_['Edad'] <= 54),
              (df_['Edad'] >= 55) & (df_['Edad'] <= 59),
              (df_['Edad'] >= 60) & (df_['Edad'] <= 64),
              (df_['Edad'] >= 65) & (df_['Edad'] <= 69),
              (df_['Edad'] >= 70) & (df_['Edad'] <= 74),
              (df_['Edad'] >= 75) & (df_['Edad'] <= 79),
              (df_['Edad'] >= 80)]
df_['edad_grupo'] = np.select(condiciones, choice_list, default='Not Specified')

# %%
año_inicio = str(input('Ingresar año de inicio:'))
año_fin = str(input('Ingresar año de finalización:'))
poblacion_mitad_periodo = int(input('Ingresar año a mitad del periodo:'))
nivel_territorial = input('Seleccionar entre nacional o Antofagasta')
filtro = "ANO_DEF >="+año_inicio+"& ANO_DEF <="+año_fin

if nivel_territorial == "nacional":
    df_trienio = df.query(filtro)
elif nivel_territorial == "Antofagasta":
    df_trienio = df.query(filtro).query('REG_RES == 2')
# Out:
# Ingresar año de inicio: 2013
# Ingresar año de finalización: 2015
# Ingresar año a mitad del periodo: 2014
# Seleccionar entre nacional o Antofagasta Antofagasta

# %% [markdown]
# # Numerador

# %%
df_pais = df_trienio.groupby(['CAPITULO_DIAG1', 'GLOSA_CAPITULO_DIAG1' ], as_index = False)['DIA_DEF'].count().rename(columns={'DIA_DEF':'num_muertes', 
                                                                                                                'CAPITULO_DIAG1':'diag1_cap',
                                                                                                                'GLOSA_CAPITULO_DIAG1':'diag1_cap_glosa'})

# %% [markdown]
# # Denominador

# %%
df_['conteo']= 1
poblacion_seleccion = 'Poblacion'+' '+str(poblacion_mitad_periodo)

if nivel_territorial == "nacional":
    df_pais['pob_riesgo'] = df_.groupby('conteo')[poblacion_seleccion].sum().values.tolist()[0]
elif nivel_territorial == "Antofagasta":
    df_ = df_.query('Region == 2').copy()
    df_pais['pob_riesgo'] = df_.groupby('conteo')[poblacion_seleccion].sum().values.tolist()[0]

# %%
base = 100000
df_pais['tmb'] = round((df_pais['num_muertes']/3)/df_pais['pob_riesgo']*base,2)

# %%
df_pais
# Out:
#    diag1_cap                                    diag1_cap_glosa  num_muertes  \
# 0    A00-B99    Ciertas enfermedades infecciosas y parasitarias          250
# 1    C00-D48                               Tumores [Neoplasias]         2515
# 2    D50-D89  Enfermedades de la sangre y de los órganos hem...           46
# 3    E00-E90  Enfermedades endocrinas, nutricionales y metab...          510
# 4    F00-F99           Trastornos mentales y del comportamiento          187
# 5    G00-G99          Enfermedades del sistema nervioso central          293
# 6    I00-I99             Enfermedades del sistema circulatorio          2192
# 7    J00-J99             Enfermedades del sistema respiratorio           797
# 8    K00-K93                 Enfermedades del sistema digestivo          610
# 9    L00-L99    Enfermedades de la piel y del tejido subcutáneo           38
# 10   M00-M99  Enfermedades del sistema osteomuscular y del t...           46
# 11   N00-N99            Enfermedades del sistema genitourinario          298
# 12   O00-O99                        Embarazo, parto y puerperio           10
# 13   P00-P96  Ciertas afecciones originadas en el período pe...          106
# 14   Q00-Q99  Malformaciones congénitas, deformidades y anom...           98
# 15   R00-R99  Síntomas, signos y hallazgos anormales clínico...          231
# 16   S00-T98  Traumatismos, envenenamientos y algunas otras ...          757
#
#     pob_riesgo     tmb
# 0       596155   13.98
# 1       596155  140.62
# 2       596155    2.57
# 3       596155   28.52
# 4       596155   10.46
# 5       596155   16.38
# 6       596155  122.56
# 7       596155   44.56
# 8       596155   34.11
# 9       596155    2.12
# 10      596155    2.57
# 11      596155   16.66
# 12      596155    0.56
# 13      596155    5.93
# 14      596155    5.48
# 15      596155   12.92
# 16      596155   42.33

# %% [markdown]
# # TMB por sexo

# %%
df_hombres = df_trienio.query('SEXO == 1').groupby(['CAPITULO_DIAG1', 'GLOSA_CAPITULO_DIAG1' ], as_index = False)['DIA_DEF'].count().rename(columns={'DIA_DEF':'num_muertes_hombres', 
                                                                                                                'CAPITULO_DIAG1':'diag1_cap',
                                                                                                                'GLOSA_CAPITULO_DIAG1':'diag1_cap_glosa'})
df_mujeres = df_trienio.query('SEXO == 2').groupby(['CAPITULO_DIAG1', 'GLOSA_CAPITULO_DIAG1' ], as_index = False)['DIA_DEF'].count().rename(columns={'DIA_DEF':'num_muertes_mujeres', 
                                                                                                                'CAPITULO_DIAG1':'diag1_cap',
                                                                                                                'GLOSA_CAPITULO_DIAG1':'diag1_cap_glosa'})

# %%
df_hombres['pob_riesgo_hombres'] = df_.query('Sexo == 1').groupby('conteo')[poblacion_seleccion].sum().values.tolist()[0]
df_mujeres['pob_riesgo_mujeres'] = df_.query('Sexo == 2').groupby('conteo')[poblacion_seleccion].sum().values.tolist()[0]

df_hombres['tmb_hombres'] = round((df_hombres['num_muertes_hombres']/3)/df_hombres['pob_riesgo_hombres']*base,2)
df_mujeres['tmb_mujeres'] = round((df_mujeres['num_muertes_mujeres']/3)/df_mujeres['pob_riesgo_mujeres']*base,2)

# %%
df_hombres
# Out:
#    diag1_cap                                    diag1_cap_glosa  \
# 0    A00-B99    Ciertas enfermedades infecciosas y parasitarias
# 1    C00-D48                               Tumores [Neoplasias]
# 2    D50-D89  Enfermedades de la sangre y de los órganos hem...
# 3    E00-E90  Enfermedades endocrinas, nutricionales y metab...
# 4    F00-F99           Trastornos mentales y del comportamiento
# 5    G00-G99          Enfermedades del sistema nervioso central
# 6    I00-I99             Enfermedades del sistema circulatorio
# 7    J00-J99             Enfermedades del sistema respiratorio
# 8    K00-K93                 Enfermedades del sistema digestivo
# 9    L00-L99    Enfermedades de la piel y del tejido subcutáneo
# 10   M00-M99  Enfermedades del sistema osteomuscular y del t...
# 11   N00-N99            Enfermedades del sistema genitourinario
# 12   P00-P96  Ciertas afecciones originadas en el período pe...
# 13   Q00-Q99  Malformaciones congénitas, deformidades y anom...
# 14   R00-R99  Síntomas, signos y hallazgos anormales clínico...
# 15   S00-T98  Traumatismos, envenenamientos y algunas otras ...
#
#     num_muertes_hombres  pob_riesgo_hombres  tmb_hombres
# 0                   153              302118        16.88
# 1                  1435              302118       158.33
# 2                    25              302118         2.76
# 3                   269              302118        29.68
# 4                    65              302118         7.17
# 5                   125              302118        13.79
# 6                  1208              302118       133.28
# 7                   434              302118        47.88
# 8                   397              302118        43.80
# 9                    12              302118         1.32
# 10                   16              302118         1.77
# 11                  146              302118        16.11
# 12                   59              302118         6.51
# 13                   42              302118         4.63
# 14                  112              302118        12.36
# 15                  565              302118        62.34

# %%
df_mujeres
# Out:
#    diag1_cap                                    diag1_cap_glosa  \
# 0    A00-B99    Ciertas enfermedades infecciosas y parasitarias
# 1    C00-D48                               Tumores [Neoplasias]
# 2    D50-D89  Enfermedades de la sangre y de los órganos hem...
# 3    E00-E90  Enfermedades endocrinas, nutricionales y metab...
# 4    F00-F99           Trastornos mentales y del comportamiento
# 5    G00-G99          Enfermedades del sistema nervioso central
# 6    I00-I99             Enfermedades del sistema circulatorio
# 7    J00-J99             Enfermedades del sistema respiratorio
# 8    K00-K93                 Enfermedades del sistema digestivo
# 9    L00-L99    Enfermedades de la piel y del tejido subcutáneo
# 10   M00-M99  Enfermedades del sistema osteomuscular y del t...
# 11   N00-N99            Enfermedades del sistema genitourinario
# 12   O00-O99                        Embarazo, parto y puerperio
# 13   P00-P96  Ciertas afecciones originadas en el período pe...
# 14   Q00-Q99  Malformaciones congénitas, deformidades y anom...
# 15   R00-R99  Síntomas, signos y hallazgos anormales clínico...
# 16   S00-T98  Traumatismos, envenenamientos y algunas otras ...
#
#     num_muertes_mujeres  pob_riesgo_mujeres  tmb_mujeres
# 0                    97              294037        11.00
# 1                  1080              294037       122.43
# 2                    21              294037         2.38
# 3                   241              294037        27.32
# 4                   122              294037        13.83
# 5                   168              294037        19.05
# 6                   984              294037       111.55
# 7                   363              294037        41.15
# 8                   213              294037        24.15
# 9                    26              294037         2.95
# 10                   30              294037         3.40
# 11                  152              294037        17.23
# 12                   10              294037         1.13
# 13                   47              294037         5.33
# 14                   53              294037         6.01
# 15                  119              294037        13.49
# 16                  192              294037        21.77

# %%
capitulos = df_mujeres['diag1_cap'].values.tolist()
nom_capitulos = df_mujeres['diag1_cap_glosa'].values.tolist()
if len(capitulos) == len(nom_capitulos):
    print("capítulo y nom_capitulos tienen el mismo largo")
# Out:
# capítulo y nom_capitulos tienen el mismo largo

# %%
lista_completa = list()
contador = 0
for i in capitulos:
    valor = [i, nom_capitulos[contador]]
    lista_completa.append(valor)
    contador += 1
print(f"largo lista completa de capítulos: {len(lista_completa)}")
# Out:
# largo lista completa de capítulos: 17

# %%
hombres = df_hombres.sort_values(by=['diag1_cap'])
variables_hombres = df_hombres.values.tolist()
largo_capitulo = df_hombres['diag1_cap'].values.tolist()
       
if len(largo_capitulo) < len(lista_completa):
        print(f"El largo de la columna diag1_cap es: {len(largo_capitulo)} y debería ser {len(lista_completa)}")
        

        contador = 0
            
        for i in lista_completa:
            if i[0] == variables_hombres[contador][0]:
                #print(f"contador = {contador}")
                #print(variables_hombres[contador][0])
                contador += 1
            elif i[0] != variables_hombres[contador][0]:
                print(f"valor de la lista completa = {lista_completa[contador]}")
                valor = [i[0], i[1], 0, 0, 0]
                print(f"valor que será añadido {valor} en la posición {contador}")
                variables_hombres.insert(contador, valor)
                contador += 1 
            #else:
                #print(f"variables_ahombres anterior = {variables_ahombres[contador-1]}, en la posición = {contador-1}")
                #print(f"lista_completa actual = {lista_completa[contador]}")
                #print(f"variables_ahombres actual = {variables_ahombres[contador]}, en la posición = {contador}")
                #valor = [i[1], i[2], i[0], 0]
                #print(f"valor que será añadido {valor} en la posición {contador}")
                #variables_ahombres.insert(contador, valor)
                #contador += 1
else:
    print("Son del mismo largo, no hay que hacer nada!!")
                
print(f"\nLargos después del procedimiento de valores faltantes:\nLargo de a_hombres :{len(variables_hombres)} de {len(lista_completa)}")
# Out:
# El largo de la columna diag1_cap es: 16 y debería ser 17
# valor de la lista completa = ['O00-O99', 'Embarazo, parto y puerperio']
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', 0, 0, 0] en la posición 12
#
# Largos después del procedimiento de valores faltantes:
# Largo de a_hombres :17 de 17

# %%
mujeres = df_mujeres.sort_values(by=['diag1_cap'])
variables_mujeres = df_mujeres.values.tolist()
largo_capitulo = df_mujeres['diag1_cap'].values.tolist()
       
if len(largo_capitulo) < len(lista_completa):
        print(f"El largo de la columna diag1_cap es: {len(largo_capitulo)} y debería ser {len(lista_completa)}")
        

        contador = 0
            
        for i in lista_completa:
            if i[0] == variables_mujeres[contador][0]:
                #print(f"contador = {contador}")
                #print(variables_hombres[contador][0])
                contador += 1
            elif i[0] != variables_mujeres[contador][0]:
                print(f"valor de la lista completa = {lista_completa[contador]}")
                valor = [i[0], i[1], 0, 0, 0]
                print(f"valor que será añadido {valor} en la posición {contador}")
                variables_mujeres.insert(contador, valor)
                contador += 1 
            #else:
                #print(f"variables_ahombres anterior = {variables_ahombres[contador-1]}, en la posición = {contador-1}")
                #print(f"lista_completa actual = {lista_completa[contador]}")
                #print(f"variables_ahombres actual = {variables_ahombres[contador]}, en la posición = {contador}")
                #valor = [i[1], i[2], i[0], 0]
                #print(f"valor que será añadido {valor} en la posición {contador}")
                #variables_ahombres.insert(contador, valor)
                #contador += 1
else:
    print("Son del mismo largo, no hay que hacer nada!!")
                
print(f"\nLargos después del procedimiento de valores faltantes:\nLargo de mujeres :{len(variables_mujeres)} de {len(lista_completa)}")
# Out:
# Son del mismo largo, no hay que hacer nada!!
#
# Largos después del procedimiento de valores faltantes:
# Largo de mujeres :17 de 17

# %%
df_hombres = pd.DataFrame(variables_hombres, columns=['diag1_cap','diag1_cap_glosa','num_muertes_hombres', 'pob_riesgo_hombres', 'tmb_hombres'])
df_mujeres = pd.DataFrame(variables_mujeres, columns=['diag1_cap','diag1_cap_glosa','num_muertes_mujeres', 'pob_riesgo_mujeres', 'tmb_mujeres'])

# %%
df_hombres
# Out:
#    diag1_cap                                    diag1_cap_glosa  \
# 0    A00-B99    Ciertas enfermedades infecciosas y parasitarias
# 1    C00-D48                               Tumores [Neoplasias]
# 2    D50-D89  Enfermedades de la sangre y de los órganos hem...
# 3    E00-E90  Enfermedades endocrinas, nutricionales y metab...
# 4    F00-F99           Trastornos mentales y del comportamiento
# 5    G00-G99          Enfermedades del sistema nervioso central
# 6    I00-I99             Enfermedades del sistema circulatorio
# 7    J00-J99             Enfermedades del sistema respiratorio
# 8    K00-K93                 Enfermedades del sistema digestivo
# 9    L00-L99    Enfermedades de la piel y del tejido subcutáneo
# 10   M00-M99  Enfermedades del sistema osteomuscular y del t...
# 11   N00-N99            Enfermedades del sistema genitourinario
# 12   O00-O99                        Embarazo, parto y puerperio
# 13   P00-P96  Ciertas afecciones originadas en el período pe...
# 14   Q00-Q99  Malformaciones congénitas, deformidades y anom...
# 15   R00-R99  Síntomas, signos y hallazgos anormales clínico...
# 16   S00-T98  Traumatismos, envenenamientos y algunas otras ...
#
#     num_muertes_hombres  pob_riesgo_hombres  tmb_hombres
# 0                   153              302118        16.88
# 1                  1435              302118       158.33
# 2                    25              302118         2.76
# 3                   269              302118        29.68
# 4                    65              302118         7.17
# 5                   125              302118        13.79
# 6                  1208              302118       133.28
# 7                   434              302118        47.88
# 8                   397              302118        43.80
# 9                    12              302118         1.32
# 10                   16              302118         1.77
# 11                  146              302118        16.11
# 12                    0                   0         0.00
# 13                   59              302118         6.51
# 14                   42              302118         4.63
# 15                  112              302118        12.36
# 16                  565              302118        62.34

# %%
df_mujeres
# Out:
#    diag1_cap                                    diag1_cap_glosa  \
# 0    A00-B99    Ciertas enfermedades infecciosas y parasitarias
# 1    C00-D48                               Tumores [Neoplasias]
# 2    D50-D89  Enfermedades de la sangre y de los órganos hem...
# 3    E00-E90  Enfermedades endocrinas, nutricionales y metab...
# 4    F00-F99           Trastornos mentales y del comportamiento
# 5    G00-G99          Enfermedades del sistema nervioso central
# 6    I00-I99             Enfermedades del sistema circulatorio
# 7    J00-J99             Enfermedades del sistema respiratorio
# 8    K00-K93                 Enfermedades del sistema digestivo
# 9    L00-L99    Enfermedades de la piel y del tejido subcutáneo
# 10   M00-M99  Enfermedades del sistema osteomuscular y del t...
# 11   N00-N99            Enfermedades del sistema genitourinario
# 12   O00-O99                        Embarazo, parto y puerperio
# 13   P00-P96  Ciertas afecciones originadas en el período pe...
# 14   Q00-Q99  Malformaciones congénitas, deformidades y anom...
# 15   R00-R99  Síntomas, signos y hallazgos anormales clínico...
# 16   S00-T98  Traumatismos, envenenamientos y algunas otras ...
#
#     num_muertes_mujeres  pob_riesgo_mujeres  tmb_mujeres
# 0                    97              294037        11.00
# 1                  1080              294037       122.43
# 2                    21              294037         2.38
# 3                   241              294037        27.32
# 4                   122              294037        13.83
# 5                   168              294037        19.05
# 6                   984              294037       111.55
# 7                   363              294037        41.15
# 8                   213              294037        24.15
# 9                    26              294037         2.95
# 10                   30              294037         3.40
# 11                  152              294037        17.23
# 12                   10              294037         1.13
# 13                   47              294037         5.33
# 14                   53              294037         6.01
# 15                  119              294037        13.49
# 16                  192              294037        21.77

# %% [markdown]
# # Ajuste de la tasa

# %%
a_hombres = df_trienio.query('SEXO == 1')
a_mujeres = df_trienio.query('SEXO == 2')

a_hombres = a_hombres.groupby(['CAPITULO_DIAG1', 'GLOSA_CAPITULO_DIAG1', 'edad_grupo'], as_index = False)['DIA_DEF'].count().rename(columns={'DIA_DEF':'num_muertes', 
                                                                                                                'CAPITULO_DIAG1':'diag1_cap',
                                                                                                                'GLOSA_CAPITULO_DIAG1':'diag1_cap_glosa'})

a_mujeres = a_mujeres.groupby(['CAPITULO_DIAG1', 'GLOSA_CAPITULO_DIAG1', 'edad_grupo'], as_index = False)['DIA_DEF'].count().rename(columns={'DIA_DEF':'num_muertes', 
                                                                                                                'CAPITULO_DIAG1':'diag1_cap',
                                                                                                                'GLOSA_CAPITULO_DIAG1':'diag1_cap_glosa'})

# %%
print(f"largo de a_hombres = {len(a_hombres)}, largo de a_mujeres = {len(a_mujeres)}")
# Out:
# largo de a_hombres = 191, largo de a_mujeres = 185

# %%
a_hombres.sort_values(by=['diag1_cap', 'edad_grupo'])
# Out:
#     diag1_cap                                    diag1_cap_glosa  edad_grupo  \
# 0     A00-B99    Ciertas enfermedades infecciosas y parasitarias  00-04 años
# 1     A00-B99    Ciertas enfermedades infecciosas y parasitarias  05-09 años
# 2     A00-B99    Ciertas enfermedades infecciosas y parasitarias  20-24 años
# 3     A00-B99    Ciertas enfermedades infecciosas y parasitarias  25-29 años
# 4     A00-B99    Ciertas enfermedades infecciosas y parasitarias  30-34 años
# ..        ...                                                ...         ...
# 186   S00-T98  Traumatismos, envenenamientos y algunas otras ...  60-64 años
# 187   S00-T98  Traumatismos, envenenamientos y algunas otras ...  65-69 años
# 188   S00-T98  Traumatismos, envenenamientos y algunas otras ...  70-74 años
# 189   S00-T98  Traumatismos, envenenamientos y algunas otras ...  75-79 años
# 190   S00-T98  Traumatismos, envenenamientos y algunas otras ...    80 y más
#
#      num_muertes
# 0              2
# 1              1
# 2              4
# 3              6
# 4              5
# ..           ...
# 186           32
# 187           22
# 188           17
# 189           11
# 190           26
#
# [191 rows x 4 columns]

# %%
a_mujeres_para_nombres = a_mujeres.sort_values(by = ['diag1_cap', 'edad_grupo']).groupby(['diag1_cap','diag1_cap_glosa'], as_index = False).sum()
nom_capitulos = a_mujeres_para_nombres['diag1_cap_glosa'].values.tolist()
a_mujeres_para_capitulos = a_mujeres.sort_values(by = ['diag1_cap', 'edad_grupo']).groupby(['diag1_cap','diag1_cap_glosa'], as_index = False).sum()
lista_capitulos = a_mujeres_para_nombres['diag1_cap'].values.tolist()

# %%
edades_grupo = ['00-04 años','05-09 años','10-14 años',
              '15-19 años', '20-24 años', '25-29 años',
              '30-34 años', '35-39 años', '40-44 años',
              '45-49 años', '50-54 años', '55-59 años',
              '60-64 años', '65-69 años', '70-74 años',
              '75-79 años', '80 y más']*len(a_mujeres_para_nombres['diag1_cap'].values.tolist())
capitulos = ['A00-B99',
             'C00-D48',
             'D50-D89',
             'E00-E90',
             'F00-F99',
             'G00-G99',
             'H60-H95',
             'I00-I99',
             'J00-J99',
             'K00-K93',
             'L00-L99',
             'M00-M99',
             'N00-N99',
             'O00-O99',
             'P00-P96',
             'Q00-Q99',
             'R00-R99',
             'S00-T98']

# %%
cap_completos = list()
for i in lista_capitulos:
    for v in range(0,17):
        cap_completos.append(i)
print(f"largo lista capítulos: {len(cap_completos)}")

nom_cap_completos = list()
for i in nom_capitulos:
    for a in range(0,17):
        nom_cap_completos.append(i)
print(f"largo lista capítulos_nombres: {len(nom_cap_completos)}")
        
lista_completa = list()
contador = 0
for i in edades_grupo:
    valor = [i, cap_completos[contador], nom_cap_completos[contador]]
    lista_completa.append(valor)
    contador += 1
print(f"largo lista completa de capítulos: {len(lista_completa)}")
# Out:
# largo lista capítulos: 289
# largo lista capítulos_nombres: 289
# largo lista completa de capítulos: 289

# %%
len(a_mujeres_para_nombres['diag1_cap'].values.tolist())
# Out:
# 17

# %%
a_hombres = a_hombres.sort_values(by=['diag1_cap', 'edad_grupo'])
variables_ahombres = a_hombres.values.tolist()
largo_edad = a_hombres['edad_grupo'].values.tolist()
largo_capitulo = set(a_hombres['diag1_cap'].values.tolist())
       
if len(largo_edad) < len(lista_completa):
        print(f"El largo de la columna edad_grupo es: {len(largo_edad)} y debería ser {len(lista_completa)}")
        
        contador = 0
            
        for i in lista_completa:
            if i[0] == variables_ahombres[contador][2] and i[1] == variables_ahombres[contador][0]:
                #print(f"contador = {contador}")
                #print(variables_ahombres[contador][2])
                contador += 1
            elif i[0] != variables_ahombres[contador][2] and i[1] != variables_ahombres[contador][0]:   
                #print(f"valor de la lista completa = {lista_completa[contador]}")
                valor = [i[1], i[2], i[0], 0]
                print(f"valor que será añadido {valor} en la posición {contador}")
                variables_ahombres.insert(contador, valor)
                contador += 1 
            else:
                #print(f"variables_ahombres anterior = {variables_ahombres[contador-1]}, en la posición = {contador-1}")
                #print(f"lista_completa actual = {lista_completa[contador]}")
                #print(f"variables_ahombres actual = {variables_ahombres[contador]}, en la posición = {contador}")
                valor = [i[1], i[2], i[0], 0]
                print(f"valor que será añadido {valor} en la posición {contador}")
                variables_ahombres.insert(contador, valor)
                contador += 1
                
print(f"\nLargos después del procedimiento de valores faltantes:\nLargo de a_hombres :{len(variables_ahombres)} de {len(lista_completa)}")
# Out:
# El largo de la columna edad_grupo es: 191 y debería ser 289
# valor que será añadido ['A00-B99', 'Ciertas enfermedades infecciosas y parasitarias', '10-14 años', 0] en la posición 2
# valor que será añadido ['A00-B99', 'Ciertas enfermedades infecciosas y parasitarias', '15-19 años', 0] en la posición 3
# valor que será añadido ['C00-D48', 'Tumores [Neoplasias]', '00-04 años', 0] en la posición 17
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '05-09 años', 0] en la posición 35
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '10-14 años', 0] en la posición 36
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '15-19 años', 0] en la posición 37
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '25-29 años', 0] en la posición 39
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '30-34 años', 0] en la posición 40
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '45-49 años', 0] en la posición 43
# valor que será añadido ['E00-E90', 'Enfermedades endocrinas, nutricionales y metabólicas', '05-09 años', 0] en la posición 52
# valor que será añadido ['E00-E90', 'Enfermedades endocrinas, nutricionales y metabólicas', '20-24 años', 0] en la posición 55
# valor que será añadido ['E00-E90', 'Enfermedades endocrinas, nutricionales y metabólicas', '25-29 años', 0] en la posición 56
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '00-04 años', 0] en la posición 68
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '05-09 años', 0] en la posición 69
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '10-14 años', 0] en la posición 70
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '15-19 años', 0] en la posición 71
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '20-24 años', 0] en la posición 72
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '25-29 años', 0] en la posición 73
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '30-34 años', 0] en la posición 74
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '50-54 años', 0] en la posición 78
# valor que será añadido ['G00-G99', 'Enfermedades del sistema nervioso central', '15-19 años', 0] en la posición 88
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '00-04 años', 0] en la posición 102
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '05-09 años', 0] en la posición 103
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '15-19 años', 0] en la posición 105
# valor que será añadido ['J00-J99', 'Enfermedades del sistema respiratorio ', '05-09 años', 0] en la posición 120
# valor que será añadido ['J00-J99', 'Enfermedades del sistema respiratorio ', '10-14 años', 0] en la posición 121
# valor que será añadido ['J00-J99', 'Enfermedades del sistema respiratorio ', '15-19 años', 0] en la posición 122
# valor que será añadido ['J00-J99', 'Enfermedades del sistema respiratorio ', '20-24 años', 0] en la posición 123
# valor que será añadido ['K00-K93', 'Enfermedades del sistema digestivo', '05-09 años', 0] en la posición 137
# valor que será añadido ['K00-K93', 'Enfermedades del sistema digestivo', '10-14 años', 0] en la posición 138
# valor que será añadido ['K00-K93', 'Enfermedades del sistema digestivo', '15-19 años', 0] en la posición 139
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '00-04 años', 0] en la posición 153
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '05-09 años', 0] en la posición 154
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '10-14 años', 0] en la posición 155
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '15-19 años', 0] en la posición 156
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '20-24 años', 0] en la posición 157
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '25-29 años', 0] en la posición 158
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '30-34 años', 0] en la posición 159
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '35-39 años', 0] en la posición 160
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '40-44 años', 0] en la posición 161
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '60-64 años', 0] en la posición 165
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '00-04 años', 0] en la posición 170
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '10-14 años', 0] en la posición 172
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '20-24 años', 0] en la posición 174
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '25-29 años', 0] en la posición 175
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '30-34 años', 0] en la posición 176
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '35-39 años', 0] en la posición 177
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '40-44 años', 0] en la posición 178
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '65-69 años', 0] en la posición 183
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '00-04 años', 0] en la posición 187
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '05-09 años', 0] en la posición 188
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '10-14 años', 0] en la posición 189
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '15-19 años', 0] en la posición 190
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '20-24 años', 0] en la posición 191
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '30-34 años', 0] en la posición 193
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '35-39 años', 0] en la posición 194
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '00-04 años', 0] en la posición 204
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '05-09 años', 0] en la posición 205
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '10-14 años', 0] en la posición 206
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '15-19 años', 0] en la posición 207
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '20-24 años', 0] en la posición 208
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '25-29 años', 0] en la posición 209
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '30-34 años', 0] en la posición 210
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '35-39 años', 0] en la posición 211
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '40-44 años', 0] en la posición 212
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '45-49 años', 0] en la posición 213
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '50-54 años', 0] en la posición 214
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '55-59 años', 0] en la posición 215
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '60-64 años', 0] en la posición 216
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '65-69 años', 0] en la posición 217
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '70-74 años', 0] en la posición 218
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '75-79 años', 0] en la posición 219
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '80 y más', 0] en la posición 220
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '10-14 años', 0] en la posición 223
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '15-19 años', 0] en la posición 224
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '35-39 años', 0] en la posición 228
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '40-44 años', 0] en la posición 229
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '45-49 años', 0] en la posición 230
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '50-54 años', 0] en la posición 231
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '55-59 años', 0] en la posición 232
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '60-64 años', 0] en la posición 233
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '65-69 años', 0] en la posición 234
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '70-74 años', 0] en la posición 235
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '75-79 años', 0] en la posición 236
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '80 y más', 0] en la posición 237
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '05-09 años', 0] en la posición 239
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '15-19 años', 0] en la posición 241
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '30-34 años', 0] en la posición 244
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '35-39 años', 0] en la posición 245
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '40-44 años', 0] en la posición 246
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '45-49 años', 0] en la posición 247
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '50-54 años', 0] en la posición 248
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '60-64 años', 0] en la posición 250
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '70-74 años', 0] en la posición 252
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '75-79 años', 0] en la posición 253
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '80 y más', 0] en la posición 254
# valor que será añadido ['R00-R99', 'Síntomas, signos y hallazgos anormales clínicos y de laboratorio, no clasificados en otra parte', '05-09 años', 0] en la posición 256
# valor que será añadido ['R00-R99', 'Síntomas, signos y hallazgos anormales clínicos y de laboratorio, no clasificados en otra parte', '15-19 años', 0] en la posición 258
#
# Largos después del procedimiento de valores faltantes:
# Largo de a_hombres :289 de 289

# %%
a_mujeres = a_mujeres.sort_values(by=['diag1_cap', 'edad_grupo'])
variables_amujeres = a_mujeres.values.tolist()
largo_edad = a_mujeres['edad_grupo'].values.tolist()
largo_capitulo = set(a_mujeres['diag1_cap'].values.tolist())

if len(largo_edad) < len(lista_completa):
        print(f"El largo de la columna edad_grupo es: {len(largo_edad)} y debería ser 306")
        
        contador = 0

        for i in lista_completa:
            if i[0] == variables_amujeres[contador][2] and i[1] == variables_amujeres[contador][0]:
                #print(f"Contador = {contador}")
                #print(variables_amujeres[contador][2])
                contador += 1
            elif i[0] != variables_amujeres[contador][2] and i[1] != variables_amujeres[contador][0]:   
                valor = [i[1], i[2], i[0], 0]
                print(f"valor que será añadido {valor} en la posición {contador}")
                variables_amujeres.insert(contador, valor)
                contador += 1 
            else:
                #print(f"variables_amujeres = {variables_amujeres[contador]}, en la posición = {contador}")
                valor = [i[1], i[2], i[0], 0]
                print(f"valor que será añadido {valor} en la posición {contador}")
                variables_amujeres.insert(contador, valor)
                contador += 1
                
print(f"\nLargos después del procedimiento de valores faltantes:\nLargo de a_mujeres :{len(variables_amujeres)} de {len(lista_completa)}")
# Out:
# El largo de la columna edad_grupo es: 185 y debería ser 306
# valor que será añadido ['A00-B99', 'Ciertas enfermedades infecciosas y parasitarias', '05-09 años', 0] en la posición 1
# valor que será añadido ['A00-B99', 'Ciertas enfermedades infecciosas y parasitarias', '10-14 años', 0] en la posición 2
# valor que será añadido ['A00-B99', 'Ciertas enfermedades infecciosas y parasitarias', '15-19 años', 0] en la posición 3
# valor que será añadido ['A00-B99', 'Ciertas enfermedades infecciosas y parasitarias', '25-29 años', 0] en la posición 5
# valor que será añadido ['C00-D48', 'Tumores [Neoplasias]', '00-04 años', 0] en la posición 17
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '05-09 años', 0] en la posición 35
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '10-14 años', 0] en la posición 36
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '15-19 años', 0] en la posición 37
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '20-24 años', 0] en la posición 38
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '25-29 años', 0] en la posición 39
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '40-44 años', 0] en la posición 42
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '45-49 años', 0] en la posición 43
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '50-54 años', 0] en la posición 44
# valor que será añadido ['D50-D89', 'Enfermedades de la sangre y de los órganos hematopoyéticos, y ciertos trastornos que afectan el mecanismo de la inmunidad ', '55-59 años', 0] en la posición 45
# valor que será añadido ['E00-E90', 'Enfermedades endocrinas, nutricionales y metabólicas', '05-09 años', 0] en la posición 52
# valor que será añadido ['E00-E90', 'Enfermedades endocrinas, nutricionales y metabólicas', '10-14 años', 0] en la posición 53
# valor que será añadido ['E00-E90', 'Enfermedades endocrinas, nutricionales y metabólicas', '15-19 años', 0] en la posición 54
# valor que será añadido ['E00-E90', 'Enfermedades endocrinas, nutricionales y metabólicas', '20-24 años', 0] en la posición 55
# valor que será añadido ['E00-E90', 'Enfermedades endocrinas, nutricionales y metabólicas', '35-39 años', 0] en la posición 58
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '00-04 años', 0] en la posición 68
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '05-09 años', 0] en la posición 69
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '10-14 años', 0] en la posición 70
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '15-19 años', 0] en la posición 71
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '20-24 años', 0] en la posición 72
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '25-29 años', 0] en la posición 73
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '30-34 años', 0] en la posición 74
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '40-44 años', 0] en la posición 76
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '50-54 años', 0] en la posición 78
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '55-59 años', 0] en la posición 79
# valor que será añadido ['G00-G99', 'Enfermedades del sistema nervioso central', '00-04 años', 0] en la posición 85
# valor que será añadido ['G00-G99', 'Enfermedades del sistema nervioso central', '40-44 años', 0] en la posición 93
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '00-04 años', 0] en la posición 102
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '05-09 años', 0] en la posición 103
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '10-14 años', 0] en la posición 104
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '20-24 años', 0] en la posición 106
# valor que será añadido ['J00-J99', 'Enfermedades del sistema respiratorio ', '10-14 años', 0] en la posición 121
# valor que será añadido ['J00-J99', 'Enfermedades del sistema respiratorio ', '15-19 años', 0] en la posición 122
# valor que será añadido ['J00-J99', 'Enfermedades del sistema respiratorio ', '30-34 años', 0] en la posición 125
# valor que será añadido ['K00-K93', 'Enfermedades del sistema digestivo', '05-09 años', 0] en la posición 137
# valor que será añadido ['K00-K93', 'Enfermedades del sistema digestivo', '10-14 años', 0] en la posición 138
# valor que será añadido ['K00-K93', 'Enfermedades del sistema digestivo', '30-34 años', 0] en la posición 142
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '00-04 años', 0] en la posición 153
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '05-09 años', 0] en la posición 154
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '10-14 años', 0] en la posición 155
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '15-19 años', 0] en la posición 156
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '25-29 años', 0] en la posición 158
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '30-34 años', 0] en la posición 159
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '35-39 años', 0] en la posición 160
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '40-44 años', 0] en la posición 161
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '45-49 años', 0] en la posición 162
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '50-54 años', 0] en la posición 163
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '55-59 años', 0] en la posición 164
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '60-64 años', 0] en la posición 165
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '00-04 años', 0] en la posición 170
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '05-09 años', 0] en la posición 171
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '15-19 años', 0] en la posición 173
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '35-39 años', 0] en la posición 177
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '60-64 años', 0] en la posición 182
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '05-09 años', 0] en la posición 188
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '10-14 años', 0] en la posición 189
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '15-19 años', 0] en la posición 190
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '20-24 años', 0] en la posición 191
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '30-34 años', 0] en la posición 193
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '00-04 años', 0] en la posición 204
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '05-09 años', 0] en la posición 205
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '10-14 años', 0] en la posición 206
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '35-39 años', 0] en la posición 211
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '45-49 años', 0] en la posición 213
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '50-54 años', 0] en la posición 214
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '55-59 años', 0] en la posición 215
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '60-64 años', 0] en la posición 216
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '65-69 años', 0] en la posición 217
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '70-74 años', 0] en la posición 218
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '75-79 años', 0] en la posición 219
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '80 y más', 0] en la posición 220
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '05-09 años', 0] en la posición 222
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '10-14 años', 0] en la posición 223
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '15-19 años', 0] en la posición 224
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '20-24 años', 0] en la posición 225
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '25-29 años', 0] en la posición 226
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '30-34 años', 0] en la posición 227
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '35-39 años', 0] en la posición 228
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '40-44 años', 0] en la posición 229
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '45-49 años', 0] en la posición 230
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '50-54 años', 0] en la posición 231
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '55-59 años', 0] en la posición 232
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '60-64 años', 0] en la posición 233
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '65-69 años', 0] en la posición 234
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '70-74 años', 0] en la posición 235
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '75-79 años', 0] en la posición 236
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '80 y más', 0] en la posición 237
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '15-19 años', 0] en la posición 241
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '20-24 años', 0] en la posición 242
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '30-34 años', 0] en la posición 244
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '55-59 años', 0] en la posición 249
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '60-64 años', 0] en la posición 250
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '75-79 años', 0] en la posición 253
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '80 y más', 0] en la posición 254
# valor que será añadido ['R00-R99', 'Síntomas, signos y hallazgos anormales clínicos y de laboratorio, no clasificados en otra parte', '05-09 años', 0] en la posición 256
# valor que será añadido ['R00-R99', 'Síntomas, signos y hallazgos anormales clínicos y de laboratorio, no clasificados en otra parte', '10-14 años', 0] en la posición 257
# valor que será añadido ['R00-R99', 'Síntomas, signos y hallazgos anormales clínicos y de laboratorio, no clasificados en otra parte', '15-19 años', 0] en la posición 258
# valor que será añadido ['R00-R99', 'Síntomas, signos y hallazgos anormales clínicos y de laboratorio, no clasificados en otra parte', '20-24 años', 0] en la posición 259
# valor que será añadido ['R00-R99', 'Síntomas, signos y hallazgos anormales clínicos y de laboratorio, no clasificados en otra parte', '25-29 años', 0] en la posición 260
# valor que será añadido ['R00-R99', 'Síntomas, signos y hallazgos anormales clínicos y de laboratorio, no clasificados en otra parte', '30-34 años', 0] en la posición 261
#
# Largos después del procedimiento de valores faltantes:
# Largo de a_mujeres :289 de 289

# %%
a_hombres_full = pd.DataFrame(variables_ahombres, columns=['diag1_cap','diag1_cap_glosa','edad_grupo','num_muertes_hom' ])
a_mujeres_full = pd.DataFrame(variables_amujeres, columns=['diag1_cap','diag1_cap_glosa','edad_grupo','num_muertes_muj' ])

# %%
a_hombres_full
# Out:
#     diag1_cap                                    diag1_cap_glosa  edad_grupo  \
# 0     A00-B99    Ciertas enfermedades infecciosas y parasitarias  00-04 años
# 1     A00-B99    Ciertas enfermedades infecciosas y parasitarias  05-09 años
# 2     A00-B99    Ciertas enfermedades infecciosas y parasitarias  10-14 años
# 3     A00-B99    Ciertas enfermedades infecciosas y parasitarias  15-19 años
# 4     A00-B99    Ciertas enfermedades infecciosas y parasitarias  20-24 años
# ..        ...                                                ...         ...
# 284   S00-T98  Traumatismos, envenenamientos y algunas otras ...  60-64 años
# 285   S00-T98  Traumatismos, envenenamientos y algunas otras ...  65-69 años
# 286   S00-T98  Traumatismos, envenenamientos y algunas otras ...  70-74 años
# 287   S00-T98  Traumatismos, envenenamientos y algunas otras ...  75-79 años
# 288   S00-T98  Traumatismos, envenenamientos y algunas otras ...    80 y más
#
#      num_muertes_hom
# 0                  2
# 1                  1
# 2                  0
# 3                  0
# 4                  4
# ..               ...
# 284               32
# 285               22
# 286               17
# 287               11
# 288               26
#
# [289 rows x 4 columns]

# %%
a_mujeres_full
# Out:
#     diag1_cap                                    diag1_cap_glosa  edad_grupo  \
# 0     A00-B99    Ciertas enfermedades infecciosas y parasitarias  00-04 años
# 1     A00-B99    Ciertas enfermedades infecciosas y parasitarias  05-09 años
# 2     A00-B99    Ciertas enfermedades infecciosas y parasitarias  10-14 años
# 3     A00-B99    Ciertas enfermedades infecciosas y parasitarias  15-19 años
# 4     A00-B99    Ciertas enfermedades infecciosas y parasitarias  20-24 años
# ..        ...                                                ...         ...
# 284   S00-T98  Traumatismos, envenenamientos y algunas otras ...  60-64 años
# 285   S00-T98  Traumatismos, envenenamientos y algunas otras ...  65-69 años
# 286   S00-T98  Traumatismos, envenenamientos y algunas otras ...  70-74 años
# 287   S00-T98  Traumatismos, envenenamientos y algunas otras ...  75-79 años
# 288   S00-T98  Traumatismos, envenenamientos y algunas otras ...    80 y más
#
#      num_muertes_muj
# 0                  3
# 1                  0
# 2                  0
# 3                  0
# 4                  1
# ..               ...
# 284                9
# 285                7
# 286               12
# 287                7
# 288               55
#
# [289 rows x 4 columns]

# %%
print(f"Poblacion seleccionada = {poblacion_seleccion}")
poblacion_hombres = df_.query('Sexo == 1').groupby('edad_grupo')[poblacion_seleccion].sum().values.tolist()*len(a_mujeres_para_nombres['diag1_cap'].values.tolist())
poblacion_mujeres = df_.query('Sexo == 2').groupby('edad_grupo')[poblacion_seleccion].sum().values.tolist()*len(a_mujeres_para_nombres['diag1_cap'].values.tolist())
# Out:
# Poblacion seleccionada = Poblacion 2014

# %%
a_hombres_full = a_hombres_full.sort_values(by=['diag1_cap', 'edad_grupo'], ascending=True)
a_mujeres_full = a_mujeres_full.sort_values(by=['diag1_cap', 'edad_grupo'], ascending=True)

# %%
a_hombres_full['poblacion_hombres'] = poblacion_hombres
a_mujeres_full['poblacion_mujeres'] = poblacion_mujeres

# %%
a_hombres_full['tmb_hombres'] = (a_hombres_full['num_muertes_hom']/3)/a_hombres_full['poblacion_hombres']
a_mujeres_full['tmb_mujeres'] = (a_mujeres_full['num_muertes_muj']/3)/a_mujeres_full['poblacion_mujeres']

# %%
pob_estandar = [664111,631212,608801,599050,609710,587104,523869,495728,479345,436397,376512,326760,266575,192751,146575,108082,115625]*len(a_mujeres_para_nombres['diag1_cap'].values.tolist())

# %%
len(pob_estandar)
# Out:
# 289

# %%
a_hombres_full['pob_estandar'] = pob_estandar
a_mujeres_full['pob_estandar'] = pob_estandar

# %%
a_hombres_full['muertes_esperadas_hombres'] = a_hombres_full['tmb_hombres'] * a_hombres_full['pob_estandar']
a_mujeres_full['muertes_esperadas_mujeres'] = a_mujeres_full['tmb_mujeres'] * a_mujeres_full['pob_estandar']

# %%
a_mujeres_full.query('diag1_cap == "K00-K93"')
# Out:
#     diag1_cap                     diag1_cap_glosa  edad_grupo  \
# 136   K00-K93  Enfermedades del sistema digestivo  00-04 años
# 137   K00-K93  Enfermedades del sistema digestivo  05-09 años
# 138   K00-K93  Enfermedades del sistema digestivo  10-14 años
# 139   K00-K93  Enfermedades del sistema digestivo  15-19 años
# 140   K00-K93  Enfermedades del sistema digestivo  20-24 años
# 141   K00-K93  Enfermedades del sistema digestivo  25-29 años
# 142   K00-K93  Enfermedades del sistema digestivo  30-34 años
# 143   K00-K93  Enfermedades del sistema digestivo  35-39 años
# 144   K00-K93  Enfermedades del sistema digestivo  40-44 años
# 145   K00-K93  Enfermedades del sistema digestivo  45-49 años
# 146   K00-K93  Enfermedades del sistema digestivo  50-54 años
# 147   K00-K93  Enfermedades del sistema digestivo  55-59 años
# 148   K00-K93  Enfermedades del sistema digestivo  60-64 años
# 149   K00-K93  Enfermedades del sistema digestivo  65-69 años
# 150   K00-K93  Enfermedades del sistema digestivo  70-74 años
# 151   K00-K93  Enfermedades del sistema digestivo  75-79 años
# 152   K00-K93  Enfermedades del sistema digestivo    80 y más
#
#      num_muertes_muj  poblacion_mujeres  tmb_mujeres  pob_estandar  \
# 136                3              24255     0.000041        664111
# 137                0              22242     0.000000        631212
# 138                0              21366     0.000000        608801
# 139                2              22805     0.000029        599050
# 140                2              25684     0.000026        609710
# 141                1              24733     0.000013        587104
# 142                0              23151     0.000000        523869
# 143                7              22602     0.000103        495728
# 144                4              20503     0.000065        479345
# 145                6              17953     0.000111        436397
# 146               12              17617     0.000227        376512
# 147               15              15085     0.000331        326760
# 148               27              12008     0.000750        266575
# 149               27               7906     0.001138        192751
# 150               20               5784     0.001153        146575
# 151               23               4291     0.001787        108082
# 152               64               6052     0.003525        115625
#
#      muertes_esperadas_mujeres
# 136                  27.380375
# 137                   0.000000
# 138                   0.000000
# 139                  17.512241
# 140                  15.825936
# 141                   7.912559
# 142                   0.000000
# 143                  51.176828
# 144                  31.172349
# 145                  48.615496
# 146                  85.488335
# 147                 108.306265
# 148                 199.798051
# 149                 219.423096
# 150                 168.943061
# 151                 193.108522
# 152                 407.578762

# %%
a_hombres_full.groupby('diag1_cap').sum()
# Out:
#            num_muertes_hom  poblacion_hombres  tmb_hombres  pob_estandar  \
# diag1_cap
# A00-B99                153             302118     0.006620       7168207
# C00-D48               1435             302118     0.091632       7168207
# D50-D89                 25             302118     0.001499       7168207
# E00-E90                269             302118     0.018869       7168207
# F00-F99                 65             302118     0.005338       7168207
# G00-G99                125             302118     0.007658       7168207
# I00-I99               1208             302118     0.075655       7168207
# J00-J99                434             302118     0.034297       7168207
# K00-K93                397             302118     0.017154       7168207
# L00-L99                 12             302118     0.000948       7168207
# M00-M99                 16             302118     0.000642       7168207
# N00-N99                146             302118     0.010093       7168207
# O00-O99                  0             302118     0.000000       7168207
# P00-P96                 59             302118     0.000781       7168207
# Q00-Q99                 42             302118     0.000598       7168207
# R00-R99                112             302118     0.006979       7168207
# S00-T98                565             302118     0.013954       7168207
#
#            muertes_esperadas_hombres
# diag1_cap
# A00-B99                  1323.237924
# C00-D48                 14031.862982
# D50-D89                   242.252877
# E00-E90                  2731.682361
# F00-F99                   703.922249
# G00-G99                  1225.333535
# I00-I99                 11699.697613
# J00-J99                  4621.090448
# K00-K93                  3391.523698
# L00-L99                   126.868333
# M00-M99                   135.913095
# N00-N99                  1469.572325
# O00-O99                     0.000000
# P00-P96                   514.473000
# Q00-Q99                   363.214136
# R00-R99                  1109.002837
# S00-T98                  4431.801775

# %%
a_mujeres_full.groupby('diag1_cap').sum()
# Out:
#            num_muertes_muj  poblacion_mujeres  tmb_mujeres  pob_estandar  \
# diag1_cap
# A00-B99                 97             294037     0.004077       7168207
# C00-D48               1080             294037     0.046780       7168207
# D50-D89                 21             294037     0.001022       7168207
# E00-E90                241             294037     0.012178       7168207
# F00-F99                122             294037     0.006859       7168207
# G00-G99                168             294037     0.008442       7168207
# I00-I99                984             294037     0.050708       7168207
# J00-J99                363             294037     0.018553       7168207
# K00-K93                213             294037     0.009300       7168207
# L00-L99                 26             294037     0.001553       7168207
# M00-M99                 30             294037     0.001181       7168207
# N00-N99                152             294037     0.008057       7168207
# O00-O99                 10             294037     0.000140       7168207
# P00-P96                 47             294037     0.000646       7168207
# Q00-Q99                 53             294037     0.000851       7168207
# R00-R99                119             294037     0.006068       7168207
# S00-T98                192             294037     0.006429       7168207
#
#            muertes_esperadas_mujeres
# diag1_cap
# A00-B99                   724.613557
# C00-D48                  8091.717330
# D50-D89                   154.803609
# E00-E90                  1776.026163
# F00-F99                   811.793760
# G00-G99                  1170.726734
# I00-I99                  7108.721811
# J00-J99                  2582.694699
# K00-K93                  1582.241877
# L00-L99                   193.097189
# M00-M99                   225.663451
# N00-N99                  1106.666404
# O00-O99                    79.110950
# P00-P96                   428.959211
# Q00-Q99                   469.721357
# R00-R99                   828.165251
# S00-T98                  1444.617590

# %%
tma = pd.merge(a_hombres_full.groupby(['diag1_cap', 'diag1_cap_glosa'], as_index=False)[['num_muertes_hom', 'pob_estandar', 'muertes_esperadas_hombres']].sum(), a_mujeres_full.groupby(['diag1_cap', 'diag1_cap_glosa'], as_index=False)[['num_muertes_muj', 'pob_estandar', 'muertes_esperadas_mujeres']].sum())

# %%
tma['muertes_esperadas_ambos_sexos'] = tma['muertes_esperadas_hombres'] + tma['muertes_esperadas_mujeres']

# %%
tma['tma_ambos_sexos'] = round(tma['muertes_esperadas_ambos_sexos']/tma['pob_estandar']*100000,2)

# %%
tma['tma_hombres'] = round(tma['muertes_esperadas_hombres']/tma['pob_estandar']*100000,2)
tma['tma_mujeres'] = round(tma['muertes_esperadas_mujeres']/tma['pob_estandar']*100000,2)

# %%
tma.columns
# Out:
# Index(['diag1_cap', 'diag1_cap_glosa', 'num_muertes_hom', 'pob_estandar',
#        'muertes_esperadas_hombres', 'num_muertes_muj',
#        'muertes_esperadas_mujeres', 'muertes_esperadas_ambos_sexos',
#        'tma_ambos_sexos', 'tma_hombres', 'tma_mujeres'],
#       dtype='object')

# %%
tma
# Out:
#    diag1_cap                                    diag1_cap_glosa  \
# 0    A00-B99    Ciertas enfermedades infecciosas y parasitarias
# 1    C00-D48                               Tumores [Neoplasias]
# 2    D50-D89  Enfermedades de la sangre y de los órganos hem...
# 3    E00-E90  Enfermedades endocrinas, nutricionales y metab...
# 4    F00-F99           Trastornos mentales y del comportamiento
# 5    G00-G99          Enfermedades del sistema nervioso central
# 6    I00-I99             Enfermedades del sistema circulatorio
# 7    J00-J99             Enfermedades del sistema respiratorio
# 8    K00-K93                 Enfermedades del sistema digestivo
# 9    L00-L99    Enfermedades de la piel y del tejido subcutáneo
# 10   M00-M99  Enfermedades del sistema osteomuscular y del t...
# 11   N00-N99            Enfermedades del sistema genitourinario
# 12   O00-O99                        Embarazo, parto y puerperio
# 13   P00-P96  Ciertas afecciones originadas en el período pe...
# 14   Q00-Q99  Malformaciones congénitas, deformidades y anom...
# 15   R00-R99  Síntomas, signos y hallazgos anormales clínico...
# 16   S00-T98  Traumatismos, envenenamientos y algunas otras ...
#
#     num_muertes_hom  pob_estandar  muertes_esperadas_hombres  num_muertes_muj  \
# 0               153       7168207                1323.237924               97
# 1              1435       7168207               14031.862982             1080
# 2                25       7168207                 242.252877               21
# 3               269       7168207                2731.682361              241
# 4                65       7168207                 703.922249              122
# 5               125       7168207                1225.333535              168
# 6              1208       7168207               11699.697613              984
# 7               434       7168207                4621.090448              363
# 8               397       7168207                3391.523698              213
# 9                12       7168207                 126.868333               26
# 10               16       7168207                 135.913095               30
# 11              146       7168207                1469.572325              152
# 12                0       7168207                   0.000000               10
# 13               59       7168207                 514.473000               47
# 14               42       7168207                 363.214136               53
# 15              112       7168207                1109.002837              119
# 16              565       7168207                4431.801775              192
#
#     muertes_esperadas_mujeres  muertes_esperadas_ambos_sexos  tma_ambos_sexos  \
# 0                  724.613557                    2047.851481            28.57
# 1                 8091.717330                   22123.580311           308.63
# 2                  154.803609                     397.056487             5.54
# 3                 1776.026163                    4507.708524            62.88
# 4                  811.793760                    1515.716009            21.14
# 5                 1170.726734                    2396.060269            33.43
# 6                 7108.721811                   18808.419424           262.39
# 7                 2582.694699                    7203.785147           100.50
# 8                 1582.241877                    4973.765575            69.39
# 9                  193.097189                     319.965522             4.46
# 10                 225.663451                     361.576546             5.04
# 11                1106.666404                    2576.238729            35.94
# 12                  79.110950                      79.110950             1.10
# 13                 428.959211                     943.432211            13.16
# 14                 469.721357                     832.935493            11.62
# 15                 828.165251                    1937.168087            27.02
# 16                1444.617590                    5876.419365            81.98
#
#     tma_hombres  tma_mujeres
# 0         18.46        10.11
# 1        195.75       112.88
# 2          3.38         2.16
# 3         38.11        24.78
# 4          9.82        11.32
# 5         17.09        16.33
# 6        163.22        99.17
# 7         64.47        36.03
# 8         47.31        22.07
# 9          1.77         2.69
# 10         1.90         3.15
# 11        20.50        15.44
# 12         0.00         1.10
# 13         7.18         5.98
# 14         5.07         6.55
# 15        15.47        11.55
# 16        61.83        20.15

# %%
if df_pais.shape[0] == tma.shape[0]:
    df_pais['tma'] = tma['tma_ambos_sexos']
    total_muertes = 0 
    for i in df_pais['num_muertes']:
        total_muertes += i
    df_pais['porcentaje_muertes'] = round(df_pais['num_muertes']/total_muertes*100,2)
else:
    print("df_pais es más corto")

# %%
df_pais
# Out:
#    diag1_cap                                    diag1_cap_glosa  num_muertes  \
# 0    A00-B99    Ciertas enfermedades infecciosas y parasitarias          250
# 1    C00-D48                               Tumores [Neoplasias]         2515
# 2    D50-D89  Enfermedades de la sangre y de los órganos hem...           46
# 3    E00-E90  Enfermedades endocrinas, nutricionales y metab...          510
# 4    F00-F99           Trastornos mentales y del comportamiento          187
# 5    G00-G99          Enfermedades del sistema nervioso central          293
# 6    I00-I99             Enfermedades del sistema circulatorio          2192
# 7    J00-J99             Enfermedades del sistema respiratorio           797
# 8    K00-K93                 Enfermedades del sistema digestivo          610
# 9    L00-L99    Enfermedades de la piel y del tejido subcutáneo           38
# 10   M00-M99  Enfermedades del sistema osteomuscular y del t...           46
# 11   N00-N99            Enfermedades del sistema genitourinario          298
# 12   O00-O99                        Embarazo, parto y puerperio           10
# 13   P00-P96  Ciertas afecciones originadas en el período pe...          106
# 14   Q00-Q99  Malformaciones congénitas, deformidades y anom...           98
# 15   R00-R99  Síntomas, signos y hallazgos anormales clínico...          231
# 16   S00-T98  Traumatismos, envenenamientos y algunas otras ...          757
#
#     pob_riesgo     tmb     tma  porcentaje_muertes
# 0       596155   13.98   28.57                2.78
# 1       596155  140.62  308.63               27.99
# 2       596155    2.57    5.54                0.51
# 3       596155   28.52   62.88                5.68
# 4       596155   10.46   21.14                2.08
# 5       596155   16.38   33.43                3.26
# 6       596155  122.56  262.39               24.40
# 7       596155   44.56  100.50                8.87
# 8       596155   34.11   69.39                6.79
# 9       596155    2.12    4.46                0.42
# 10      596155    2.57    5.04                0.51
# 11      596155   16.66   35.94                3.32
# 12      596155    0.56    1.10                0.11
# 13      596155    5.93   13.16                1.18
# 14      596155    5.48   11.62                1.09
# 15      596155   12.92   27.02                2.57
# 16      596155   42.33   81.98                8.43

# %%
print(df_pais[['diag1_cap','diag1_cap_glosa','num_muertes','porcentaje_muertes', 'tmb', 'tma' ]].sort_values(by=['tma'], ascending=False).to_latex(index=False))
# Out:
# \begin{tabular}{llrrrr}
# \toprule
# diag1\_cap &                                    diag1\_cap\_glosa &  num\_muertes &  porcentaje\_muertes &    tmb &    tma \\
# \midrule
#   C00-D48 &                               Tumores [Neoplasias] &         2515 &               27.99 & 140.62 & 308.63 \\
#   I00-I99 &             Enfermedades del sistema circulatorio  &         2192 &               24.40 & 122.56 & 262.39 \\
#   J00-J99 &             Enfermedades del sistema respiratorio  &          797 &                8.87 &  44.56 & 100.50 \\
#   S00-T98 & Traumatismos, envenenamientos y algunas otras c... &          757 &                8.43 &  42.33 &  81.98 \\
#   K00-K93 &                 Enfermedades del sistema digestivo &          610 &                6.79 &  34.11 &  69.39 \\
#   E00-E90 & Enfermedades endocrinas, nutricionales y metabó... &          510 &                5.68 &  28.52 &  62.88 \\
#   N00-N99 &            Enfermedades del sistema genitourinario &          298 &                3.32 &  16.66 &  35.94 \\
#   G00-G99 &          Enfermedades del sistema nervioso central &          293 &                3.26 &  16.38 &  33.43 \\
#   A00-B99 &    Ciertas enfermedades infecciosas y parasitarias &          250 &                2.78 &  13.98 &  28.57 \\
#   R00-R99 & Síntomas, signos y hallazgos anormales clínicos... &          231 &                2.57 &  12.92 &  27.02 \\
#   F00-F99 &           Trastornos mentales y del comportamiento &          187 &                2.08 &  10.46 &  21.14 \\
#   P00-P96 & Ciertas afecciones originadas en el período per... &          106 &                1.18 &   5.93 &  13.16 \\
#   Q00-Q99 & Malformaciones congénitas, deformidades y anoma... &           98 &                1.09 &   5.48 &  11.62 \\
#   D50-D89 & Enfermedades de la sangre y de los órganos hema... &           46 &                0.51 &   2.57 &   5.54 \\
#   M00-M99 & Enfermedades del sistema osteomuscular y del te... &           46 &                0.51 &   2.57 &   5.04 \\
#   L00-L99 &    Enfermedades de la piel y del tejido subcutáneo &           38 &                0.42 &   2.12 &   4.46 \\
#   O00-O99 &                        Embarazo, parto y puerperio &           10 &                0.11 &   0.56 &   1.10 \\
# \bottomrule
# \end{tabular}

# %%
df_sexo = pd.merge(df_hombres, df_mujeres)

# %%
df_sexo['tma_hombres'] = tma['tma_hombres']
df_sexo['tma_mujeres'] = tma['tma_mujeres']

# %%
muertes_hombres = df_sexo['num_muertes_hombres'].values.tolist()
muertes_mujeres = df_sexo['num_muertes_mujeres'].values.tolist()
total_hombres = 0
total_mujeres = 0
for i in muertes_hombres:
    total_hombres += i
for i in muertes_mujeres:
    total_mujeres += i
    
df_sexo['porcentaje_hombres'] = round(df_sexo['num_muertes_hombres']/total_hombres*100,2)
df_sexo['porcentaje_mujeres'] = round(df_sexo['num_muertes_mujeres']/total_mujeres*100,2)

# %%
df_sexo
# Out:
#    diag1_cap                                    diag1_cap_glosa  \
# 0    A00-B99    Ciertas enfermedades infecciosas y parasitarias
# 1    C00-D48                               Tumores [Neoplasias]
# 2    D50-D89  Enfermedades de la sangre y de los órganos hem...
# 3    E00-E90  Enfermedades endocrinas, nutricionales y metab...
# 4    F00-F99           Trastornos mentales y del comportamiento
# 5    G00-G99          Enfermedades del sistema nervioso central
# 6    I00-I99             Enfermedades del sistema circulatorio
# 7    J00-J99             Enfermedades del sistema respiratorio
# 8    K00-K93                 Enfermedades del sistema digestivo
# 9    L00-L99    Enfermedades de la piel y del tejido subcutáneo
# 10   M00-M99  Enfermedades del sistema osteomuscular y del t...
# 11   N00-N99            Enfermedades del sistema genitourinario
# 12   O00-O99                        Embarazo, parto y puerperio
# 13   P00-P96  Ciertas afecciones originadas en el período pe...
# 14   Q00-Q99  Malformaciones congénitas, deformidades y anom...
# 15   R00-R99  Síntomas, signos y hallazgos anormales clínico...
# 16   S00-T98  Traumatismos, envenenamientos y algunas otras ...
#
#     num_muertes_hombres  pob_riesgo_hombres  tmb_hombres  num_muertes_mujeres  \
# 0                   153              302118        16.88                   97
# 1                  1435              302118       158.33                 1080
# 2                    25              302118         2.76                   21
# 3                   269              302118        29.68                  241
# 4                    65              302118         7.17                  122
# 5                   125              302118        13.79                  168
# 6                  1208              302118       133.28                  984
# 7                   434              302118        47.88                  363
# 8                   397              302118        43.80                  213
# 9                    12              302118         1.32                   26
# 10                   16              302118         1.77                   30
# 11                  146              302118        16.11                  152
# 12                    0                   0         0.00                   10
# 13                   59              302118         6.51                   47
# 14                   42              302118         4.63                   53
# 15                  112              302118        12.36                  119
# 16                  565              302118        62.34                  192
#
#     pob_riesgo_mujeres  tmb_mujeres  tma_hombres  tma_mujeres  \
# 0               294037        11.00        18.46        10.11
# 1               294037       122.43       195.75       112.88
# 2               294037         2.38         3.38         2.16
# 3               294037        27.32        38.11        24.78
# 4               294037        13.83         9.82        11.32
# 5               294037        19.05        17.09        16.33
# 6               294037       111.55       163.22        99.17
# 7               294037        41.15        64.47        36.03
# 8               294037        24.15        47.31        22.07
# 9               294037         2.95         1.77         2.69
# 10              294037         3.40         1.90         3.15
# 11              294037        17.23        20.50        15.44
# 12              294037         1.13         0.00         1.10
# 13              294037         5.33         7.18         5.98
# 14              294037         6.01         5.07         6.55
# 15              294037        13.49        15.47        11.55
# 16              294037        21.77        61.83        20.15
#
#     porcentaje_hombres  porcentaje_mujeres
# 0                 3.02                2.48
# 1                28.34               27.57
# 2                 0.49                0.54
# 3                 5.31                6.15
# 4                 1.28                3.11
# 5                 2.47                4.29
# 6                23.86               25.11
# 7                 8.57                9.26
# 8                 7.84                5.44
# 9                 0.24                0.66
# 10                0.32                0.77
# 11                2.88                3.88
# 12                0.00                0.26
# 13                1.17                1.20
# 14                0.83                1.35
# 15                2.21                3.04
# 16               11.16                4.90

# %%
print(df_sexo[['diag1_cap','diag1_cap_glosa','num_muertes_hombres','porcentaje_hombres', 'tmb_hombres', 'tma_hombres' ]].sort_values(by=['tma_hombres'], ascending=False).to_latex(index=False))
# Out:
# \begin{tabular}{llrrrr}
# \toprule
# diag1\_cap &                                    diag1\_cap\_glosa &  num\_muertes\_hombres &  porcentaje\_hombres &  tmb\_hombres &  tma\_hombres \\
# \midrule
#   C00-D48 &                               Tumores [Neoplasias] &                 1435 &               28.34 &       158.33 &       195.75 \\
#   I00-I99 &             Enfermedades del sistema circulatorio  &                 1208 &               23.86 &       133.28 &       163.22 \\
#   J00-J99 &             Enfermedades del sistema respiratorio  &                  434 &                8.57 &        47.88 &        64.47 \\
#   S00-T98 & Traumatismos, envenenamientos y algunas otras c... &                  565 &               11.16 &        62.34 &        61.83 \\
#   K00-K93 &                 Enfermedades del sistema digestivo &                  397 &                7.84 &        43.80 &        47.31 \\
#   E00-E90 & Enfermedades endocrinas, nutricionales y metabó... &                  269 &                5.31 &        29.68 &        38.11 \\
#   N00-N99 &            Enfermedades del sistema genitourinario &                  146 &                2.88 &        16.11 &        20.50 \\
#   A00-B99 &    Ciertas enfermedades infecciosas y parasitarias &                  153 &                3.02 &        16.88 &        18.46 \\
#   G00-G99 &          Enfermedades del sistema nervioso central &                  125 &                2.47 &        13.79 &        17.09 \\
#   R00-R99 & Síntomas, signos y hallazgos anormales clínicos... &                  112 &                2.21 &        12.36 &        15.47 \\
#   F00-F99 &           Trastornos mentales y del comportamiento &                   65 &                1.28 &         7.17 &         9.82 \\
#   P00-P96 & Ciertas afecciones originadas en el período per... &                   59 &                1.17 &         6.51 &         7.18 \\
#   Q00-Q99 & Malformaciones congénitas, deformidades y anoma... &                   42 &                0.83 &         4.63 &         5.07 \\
#   D50-D89 & Enfermedades de la sangre y de los órganos hema... &                   25 &                0.49 &         2.76 &         3.38 \\
#   M00-M99 & Enfermedades del sistema osteomuscular y del te... &                   16 &                0.32 &         1.77 &         1.90 \\
#   L00-L99 &    Enfermedades de la piel y del tejido subcutáneo &                   12 &                0.24 &         1.32 &         1.77 \\
#   O00-O99 &                        Embarazo, parto y puerperio &                    0 &                0.00 &         0.00 &         0.00 \\
# \bottomrule
# \end{tabular}

# %%
print(df_sexo[['diag1_cap','diag1_cap_glosa','num_muertes_mujeres','porcentaje_mujeres', 'tmb_mujeres', 'tma_mujeres' ]].sort_values(by=['tma_mujeres'], ascending=False).to_latex(index=False))
# Out:
# \begin{tabular}{llrrrr}
# \toprule
# diag1\_cap &                                    diag1\_cap\_glosa &  num\_muertes\_mujeres &  porcentaje\_mujeres &  tmb\_mujeres &  tma\_mujeres \\
# \midrule
#   C00-D48 &                               Tumores [Neoplasias] &                 1080 &               27.57 &       122.43 &       112.88 \\
#   I00-I99 &             Enfermedades del sistema circulatorio  &                  984 &               25.11 &       111.55 &        99.17 \\
#   J00-J99 &             Enfermedades del sistema respiratorio  &                  363 &                9.26 &        41.15 &        36.03 \\
#   E00-E90 & Enfermedades endocrinas, nutricionales y metabó... &                  241 &                6.15 &        27.32 &        24.78 \\
#   K00-K93 &                 Enfermedades del sistema digestivo &                  213 &                5.44 &        24.15 &        22.07 \\
#   S00-T98 & Traumatismos, envenenamientos y algunas otras c... &                  192 &                4.90 &        21.77 &        20.15 \\
#   G00-G99 &          Enfermedades del sistema nervioso central &                  168 &                4.29 &        19.05 &        16.33 \\
#   N00-N99 &            Enfermedades del sistema genitourinario &                  152 &                3.88 &        17.23 &        15.44 \\
#   R00-R99 & Síntomas, signos y hallazgos anormales clínicos... &                  119 &                3.04 &        13.49 &        11.55 \\
#   F00-F99 &           Trastornos mentales y del comportamiento &                  122 &                3.11 &        13.83 &        11.32 \\
#   A00-B99 &    Ciertas enfermedades infecciosas y parasitarias &                   97 &                2.48 &        11.00 &        10.11 \\
#   Q00-Q99 & Malformaciones congénitas, deformidades y anoma... &                   53 &                1.35 &         6.01 &         6.55 \\
#   P00-P96 & Ciertas afecciones originadas en el período per... &                   47 &                1.20 &         5.33 &         5.98 \\
#   M00-M99 & Enfermedades del sistema osteomuscular y del te... &                   30 &                0.77 &         3.40 &         3.15 \\
#   L00-L99 &    Enfermedades de la piel y del tejido subcutáneo &                   26 &                0.66 &         2.95 &         2.69 \\
#   D50-D89 & Enfermedades de la sangre y de los órganos hema... &                   21 &                0.54 &         2.38 &         2.16 \\
#   O00-O99 &                        Embarazo, parto y puerperio &                   10 &                0.26 &         1.13 &         1.10 \\
# \bottomrule
# \end{tabular}
