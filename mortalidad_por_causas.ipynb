# %%
import pandas as pd
import numpy as np

# %%
path = "/Users/alvaro/Documents/Data_Science/datasets/defunciones/"
path_ = "/Users/alvaro/Desktop/"

# %%
nom = "DEF_2010_2018.csv"
nom_ = "estimaciones-y-proyecciones-2002-2035-comunas.xlsx"  
defunciones = path+nom
poblacion = path_+nom_

# %%
df = pd.read_csv(defunciones, sep=';', encoding='Latin-1')
df_ = pd.read_excel(poblacion)
# Out:
# /usr/local/Cellar/jupyterlab/3.1.14_1/libexec/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (21,58,60,64,67,69,70,71,73,76,82,86,89,90,91,93,96,97,98,99,100) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
choice_list = ['00-04 años','05-09 años','10-14 años',
              '15-19 años', '20-24 años', '25-29 años',
              '30-34 años', '35-39 años', '40-44 años',
              '45-49 años', '50-54 años', '55-59 años',
              '60-64 años', '65-69 años', '70-74 años',
              '75-79 años', '80 y más']
condiciones = [(df['EDAD_TIPO'] >= 2) | (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] <= 4),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 5) & (df['EDAD_CANT'] <= 9),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 10) & (df['EDAD_CANT'] <= 14),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 15) & (df['EDAD_CANT'] <= 19),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 20) & (df['EDAD_CANT'] <= 24),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 25) & (df['EDAD_CANT'] <= 29),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 30) & (df['EDAD_CANT'] <= 34),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 35) & (df['EDAD_CANT'] <= 39),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 40) & (df['EDAD_CANT'] <= 44),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 45) & (df['EDAD_CANT'] <= 49),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 50) & (df['EDAD_CANT'] <= 54),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 55) & (df['EDAD_CANT'] <= 59),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 60) & (df['EDAD_CANT'] <= 64),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 65) & (df['EDAD_CANT'] <= 69),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 70) & (df['EDAD_CANT'] <= 74),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 75) & (df['EDAD_CANT'] <= 79),
              (df['EDAD_TIPO'] == 1) & (df['EDAD_CANT'] >= 80)]
df['edad_grupo'] = np.select(condiciones, choice_list, default='Not Specified')
condiciones = [(df_['Edad'] >= 0) & (df_['Edad'] <= 4),
              (df_['Edad'] >= 5) & (df_['Edad'] <= 9),
              (df_['Edad'] >= 10) & (df_['Edad'] <= 14),
              (df_['Edad'] >= 15) & (df_['Edad'] <= 19),
              (df_['Edad'] >= 20) & (df_['Edad'] <= 24),
              (df_['Edad'] >= 25) & (df_['Edad'] <= 29),
              (df_['Edad'] >= 30) & (df_['Edad'] <= 34),
              (df_['Edad'] >= 35) & (df_['Edad'] <= 39),
              (df_['Edad'] >= 40) & (df_['Edad'] <= 44),
              (df_['Edad'] >= 45) & (df_['Edad'] <= 49),
              (df_['Edad'] >= 50) & (df_['Edad'] <= 54),
              (df_['Edad'] >= 55) & (df_['Edad'] <= 59),
              (df_['Edad'] >= 60) & (df_['Edad'] <= 64),
              (df_['Edad'] >= 65) & (df_['Edad'] <= 69),
              (df_['Edad'] >= 70) & (df_['Edad'] <= 74),
              (df_['Edad'] >= 75) & (df_['Edad'] <= 79),
              (df_['Edad'] >= 80)]
df_['edad_grupo'] = np.select(condiciones, choice_list, default='Not Specified')

# %%
df_trienio_1 = df.query('ANO_DEF >= 2010 & ANO_DEF <= 2012')

# %% [markdown]
# # Numerador

# %%
a = df_trienio_1.groupby(['CAPITULO_DIAG1', 'GLOSA_CAPITULO_DIAG1' ], as_index = False)['DIA_DEF'].count().rename(columns={'DIA_DEF':'num_muertes', 
                                                                                                                'CAPITULO_DIAG1':'diag1_cap',
                                                                                                                'GLOSA_CAPITULO_DIAG1':'diag1_cap_glosa'})

# %% [markdown]
# # Denominador

# %%
df_['conteo']= 1
poblacion_mitad_periodo = 2011
poblacion_seleccion = 'Poblacion'+' '+str(poblacion_mitad_periodo)
df_.groupby('conteo')[poblacion_seleccion].sum().values.tolist()
# Out:
# [17254159]

# %%
a['pob_riesgo'] = df_.groupby('conteo')[poblacion_seleccion].sum().values.tolist()[0]

# %%
base = 100000
a['tmb'] = (a['num_muertes']/3)/a['pob_riesgo']*base

# %%
a
# Out:
#    diag1_cap                                    diag1_cap_glosa  num_muertes  \
# 0    A00-B99    Ciertas enfermedades infecciosas y parasitarias         5988
# 1    C00-D48                               Tumores [Neoplasias]        74091
# 2    D50-D89  Enfermedades de la sangre y de los órganos hem...         1372
# 3    E00-E90  Enfermedades endocrinas, nutricionales y metab...        14391
# 4    F00-F99           Trastornos mentales y del comportamiento         7377
# 5    G00-G99          Enfermedades del sistema nervioso central         9995
# 6    H60-H95   Enfermedades del oído y de la apófisis mastoides            4
# 7    I00-I99             Enfermedades del sistema circulatorio         80080
# 8    J00-J99             Enfermedades del sistema respiratorio         29215
# 9    K00-K93                 Enfermedades del sistema digestivo        21155
# 10   L00-L99    Enfermedades de la piel y del tejido subcutáneo          674
# 11   M00-M99  Enfermedades del sistema osteomuscular y del t...         1542
# 12   N00-N99            Enfermedades del sistema genitourinario         8895
# 13   O00-O99                        Embarazo, parto y puerperio          146
# 14   P00-P96  Ciertas afecciones originadas en el período pe...         2532
# 15   Q00-Q99  Malformaciones congénitas, deformidades y anom...         2753
# 16   R00-R99  Síntomas, signos y hallazgos anormales clínico...         7439
# 17   S00-T98  Traumatismos, envenenamientos y algunas otras ...        23971
#
#     pob_riesgo         tmb
# 0     17254159   11.568225
# 1     17254159  143.136504
# 2     17254159    2.650569
# 3     17254159   27.801993
# 4     17254159   14.251636
# 5     17254159   19.309354
# 6     17254159    0.007728
# 7     17254159  154.706661
# 8     17254159   56.440498
# 9     17254159   40.869373
# 10    17254159    1.302102
# 11    17254159    2.978992
# 12    17254159   17.184263
# 13    17254159    0.282058
# 14    17254159    4.891574
# 15    17254159    5.318524
# 16    17254159   14.371414
# 17    17254159   46.309608

# %%
a_hombres = df_trienio_1.query('SEXO == 1')
a_mujeres = df_trienio_1.query('SEXO == 2')

a_hombres = a_hombres.groupby(['CAPITULO_DIAG1', 'GLOSA_CAPITULO_DIAG1', 'edad_grupo'], as_index = False)['DIA_DEF'].count().rename(columns={'DIA_DEF':'num_muertes', 
                                                                                                                'CAPITULO_DIAG1':'diag1_cap',
                                                                                                                'GLOSA_CAPITULO_DIAG1':'diag1_cap_glosa'})

a_mujeres = a_mujeres.groupby(['CAPITULO_DIAG1', 'GLOSA_CAPITULO_DIAG1', 'edad_grupo'], as_index = False)['DIA_DEF'].count().rename(columns={'DIA_DEF':'num_muertes', 
                                                                                                                'CAPITULO_DIAG1':'diag1_cap',
                                                                                                                'GLOSA_CAPITULO_DIAG1':'diag1_cap_glosa'})

# %%
print(f"largo de a_hombres = {len(a_hombres)}, largo de a_mujeres = {len(a_mujeres)}")
# Out:
# largo de a_hombres = 250, largo de a_mujeres = 259

# %%
cap = list()
for i in variables_ahombres:
            cap.append(i[0])
        

comparador = set(cap)
print(comparador)
# Out:
# {'A00-B99', 'I00-I99', 'E00-E90', 'Q00-Q99', 'G00-G99', 'L00-L99', 'K00-K93', 'C00-D48', 'J00-J99', 'P00-P96', 'M00-M99', 'S00-T98', 'N00-N99', 'F00-F99', 'H60-H95', 'R00-R99', 'D50-D89'}

# %%
edades_grupo = ['00-04 años','05-09 años','10-14 años',
              '15-19 años', '20-24 años', '25-29 años',
              '30-34 años', '35-39 años', '40-44 años',
              '45-49 años', '50-54 años', '55-59 años',
              '60-64 años', '65-69 años', '70-74 años',
              '75-79 años', '80 y más']*17
edades_grupo_ = ['00-04 años','05-09 años','10-14 años',
              '15-19 años', '20-24 años', '25-29 años',
              '30-34 años', '35-39 años', '40-44 años',
              '45-49 años', '50-54 años', '55-59 años',
              '60-64 años', '65-69 años', '70-74 años',
              '75-79 años', '80 y más']
capitulos = ['A00-B99',
             'C00-D48',
             'D50-D89',
             'E00-E90',
             'F00-F99',
             'G00-G99',
             'H60-H95',
             'I00-I99',
             'J00-J99',
             'K00-K93',
             'L00-L99',
             'M00-M99',
             'N00-N99',
             'O00-O99',
             'P00-P96',
             'Q00-Q99',
             'R00-R99',
             'S00-T98']
capitulos_ = list()
for i in capitulos:
    for a in range(0,17):
        capitulos_.append(i)

variables_ahombres = a_hombres.values.tolist()

if len(a_hombres) < 306:
    largo_edad = a_hombres['edad_grupo'].values.tolist()
    if len(largo_edad) < 306:
            print(f"El largo de la columna edad_grupo es: {len(largo_edad)} y debería ser 306")
            contador = 0
            
            for i in edades_grupo:
                if i == variables_ahombres[contador][2]: 
                    contador += 1
                elif i != variables_ahombres[contador][2]: 
                    valor = [variables_ahombres[contador][0],variables_ahombres[contador][1], i, 0]
                    print(f"valor que será añadido {valor}")
                    variables_ahombres.insert(contador, valor)
                    contador += 1                
    print(f"\nLargos después del primer procedimiento:\nLargo de a_hombres :{len(variables_ahombres)} de 306")

    largo_capitulo = set(a_hombres['diag1_cap'].values.tolist())
    if len(largo_capitulo) < 18:
        cap = list()
        for i in variables_ahombres:
            cap.append(i[0])   
        comparador = list(set(cap))
        comparador.sort()

        contador = 0
                
        for i in capitulos:
            if i == comparador[contador]:
                contador += 1
            elif i != comparador[contador]:
                comparador.insert(contador, i)
                ## sacar nombre del capítulo que falta:
                cap_nom = list()
                for z in variables_ahombres:
                    cap_nom.append(z[1])
                comparador_nombres = list(set(cap_nom))
                nombre_capitulo = "Embarazo, parto y puerperio"
                for h in comparador_nombres:
                    if i == h:
                        nombre_capitulo += i
                    else:
                        pass
                print(f"Falta un valor en la columna diag1_cap: {i}, {nombre_capitulo}")    
                
                for a in edades_grupo_:
                    valor = [i, nombre_capitulo, a, 0]
                    print(f"valor que será añadido {valor}")
                    variables_ahombres.append(valor)                    
                contador += 1

                
        print(f"\nLargos después del segundo procedimiento:\nLargo de a_hombres :{len(variables_ahombres)} de 306")
# Out:
# El largo de la columna edad_grupo es: 250 y debería ser 306
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '00-04 años', 0]
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '05-09 años', 0]
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '10-14 años', 0]
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '20-24 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '00-04 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '05-09 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '10-14 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '15-19 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '20-24 años', 0]
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '35-39 años', 0]
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '40-44 años', 0]
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '45-49 años', 0]
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '50-54 años', 0]
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '55-59 años', 0]
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '60-64 años', 0]
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '65-69 años', 0]
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '70-74 años', 0]
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '75-79 años', 0]
# valor que será añadido ['I00-I99', 'Enfermedades del sistema circulatorio ', '80 y más', 0]
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '00-04 años', 0]
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '05-09 años', 0]
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '10-14 años', 0]
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '15-19 años', 0]
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '05-09 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '10-14 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '15-19 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '20-24 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '25-29 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '30-34 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '35-39 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '40-44 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '45-49 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '50-54 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '55-59 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '60-64 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '65-69 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '70-74 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '75-79 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '80 y más', 0]
#
# Largos después del primer procedimiento:
# Largo de a_hombres :289 de 306
# Falta un valor en la columna diag1_cap: O00-O99, Embarazo, parto y puerperio
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '00-04 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '05-09 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '10-14 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '15-19 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '20-24 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '25-29 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '30-34 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '35-39 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '40-44 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '45-49 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '50-54 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '55-59 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '60-64 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '65-69 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '70-74 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '75-79 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '80 y más', 0]
#
# Largos después del segundo procedimiento:
# Largo de a_hombres :306 de 306

# %%
edades_grupo = ['00-04 años','05-09 años','10-14 años',
              '15-19 años', '20-24 años', '25-29 años',
              '30-34 años', '35-39 años', '40-44 años',
              '45-49 años', '50-54 años', '55-59 años',
              '60-64 años', '65-69 años', '70-74 años',
              '75-79 años', '80 y más']*17
edades_grupo_ = ['00-04 años','05-09 años','10-14 años',
              '15-19 años', '20-24 años', '25-29 años',
              '30-34 años', '35-39 años', '40-44 años',
              '45-49 años', '50-54 años', '55-59 años',
              '60-64 años', '65-69 años', '70-74 años',
              '75-79 años', '80 y más']
capitulos = ['A00-B99',
             'C00-D48',
             'D50-D89',
             'E00-E90',
             'F00-F99',
             'G00-G99',
             'H60-H95',
             'I00-I99',
             'J00-J99',
             'K00-K93',
             'L00-L99',
             'M00-M99',
             'N00-N99',
             'O00-O99',
             'P00-P96',
             'Q00-Q99',
             'R00-R99',
             'S00-T98']
capitulos_ = list()
for i in capitulos:
    for a in range(0,17):
        capitulos_.append(i)

variables_amujeres = a_mujeres.values.tolist()

if len(a_mujeres) < 306:
    largo_edad = a_mujeres['edad_grupo'].values.tolist()
    if len(largo_edad) < 306:
            print(f"El largo de la columna edad_grupo es: {len(largo_edad)} y debería ser 306")
            contador = 0
            
            for i in edades_grupo:
                if i == variables_amujeres[contador][2]: 
                    contador += 1
                elif i != variables_amujeres[contador][2]: 
                    valor = [variables_amujeres[contador][0],variables_amujeres[contador][1], i, 0]
                    print(f"valor que será añadido {valor}")
                    variables_amujeres.insert(contador, valor)
                    contador += 1                
    print(f"\nLargos después del primer procedimiento:\nLargo de variables_amujeres :{len(variables_amujeres)} de 306")

    largo_capitulo = set(a_mujeres['diag1_cap'].values.tolist())
    if len(largo_capitulo) < 18:
        cap = list()
        for i in variables_amujeres:
            cap.append(i[0])   
        comparador = list(set(cap))
        comparador.sort()

        contador = 0
                
        for i in capitulos:
            if i == comparador[contador]:
                contador += 1
            elif i != comparador[contador]:
                comparador.insert(contador, i)
                ## sacar nombre del capítulo que falta:
                cap_nom = list()
                for z in variables_amujeres:
                    cap_nom.append(z[1])
                comparador_nombres = list(set(cap_nom))
                nombre_capitulo = "Embarazo, parto y puerperio"
                for h in comparador_nombres:
                    if i == h:
                        nombre_capitulo += i
                    else:
                        pass
                print(f"Falta un valor en la columna diag1_cap: {i}, {nombre_capitulo}")    
                
                for a in edades_grupo_:
                    valor = [i, nombre_capitulo, a, 0]
                    print(f"valor que será añadido {valor}")
                    variables_amujeres.append(valor)                    
                contador += 1

                
        print(f"\nLargos después del segundo procedimiento:\nLargo de a_hombres :{len(variables_ahombres)} de 306")
    else:
        print("Están todos los capìtulos, no es necesario agregar ninguno")
# Out:
# El largo de la columna edad_grupo es: 259 y debería ser 306
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '00-04 años', 0]
# valor que será añadido ['F00-F99', 'Trastornos mentales y del comportamiento', '05-09 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '00-04 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '05-09 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '10-14 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '15-19 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '20-24 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '25-29 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '30-34 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '35-39 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '40-44 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '45-49 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '50-54 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '55-59 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '60-64 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '65-69 años', 0]
# valor que será añadido ['H60-H95', 'Enfermedades del oído y de la apófisis mastoides', '70-74 años', 0]
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '00-04 años', 0]
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '05-09 años', 0]
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '10-14 años', 0]
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '30-34 años', 0]
# valor que será añadido ['L00-L99', 'Enfermedades de la piel y del tejido subcutáneo', '40-44 años', 0]
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '00-04 años', 0]
# valor que será añadido ['M00-M99', 'Enfermedades del sistema osteomuscular y del tejido conjuntivo', '05-09 años', 0]
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '05-09 años', 0]
# valor que será añadido ['N00-N99', 'Enfermedades del sistema genitourinario', '10-14 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '00-04 años', 0]
# valor que será añadido ['O00-O99', 'Embarazo, parto y puerperio', '05-09 años', 0]
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '50-54 años', 0]
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '55-59 años', 0]
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '60-64 años', 0]
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '65-69 años', 0]
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '70-74 años', 0]
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '75-79 años', 0]
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '80 y más', 0]
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '05-09 años', 0]
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '20-24 años', 0]
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '25-29 años', 0]
# valor que será añadido ['P00-P96', 'Ciertas afecciones originadas en el período perinatal', '35-39 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '45-49 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '50-54 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '55-59 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '60-64 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '65-69 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '70-74 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '75-79 años', 0]
# valor que será añadido ['Q00-Q99', 'Malformaciones congénitas, deformidades y anomalías cromosómicas', '80 y más', 0]
#
# Largos después del primer procedimiento:
# Largo de variables_amujeres :306 de 306
# Están todos los capìtulos, no es necesario agregar ninguno

# %%
a_hombres_full = pd.DataFrame(variables_ahombres, columns=['diag1_cap','diag1_cap_glosa','edad_grupo','num_muertes' ])
a_mujeres_full = pd.DataFrame(variables_amujeres, columns=['diag1_cap','diag1_cap_glosa','edad_grupo','num_muertes' ])

# %%
a_hombres_full.groupby('diag1_cap').sum()
# Out:
#            num_muertes
# diag1_cap
# A00-B99           3499
# C00-D48          38632
# D50-D89            643
# E00-E90           6916
# F00-F99           2799
# G00-G99           4549
# H60-H95              2
# I00-I99          40763
# J00-J99          14575
# K00-K93          12788
# L00-L99            260
# M00-M99            421
# N00-N99           4125
# O00-O99              0
# P00-P96           1469
# Q00-Q99           1389
# R00-R99           3486
# S00-T98          18269
